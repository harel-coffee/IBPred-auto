# %% [markdown]
# ### Import necessary packages

# %%
import os
import time
import joblib
import random
import warnings
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import f_classif
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import matthews_corrcoef, accuracy_score
from sklearn.metrics import balanced_accuracy_score, roc_auc_score, roc_curve
from ClfSearchCV import RF_GridCV, SVM_BayesCV, DT_BayesCV
from ClfSearchCV import RF_BayesCV, NB_BayesCV, ABC_BayesCV
from PseCKSAAP import PseCKSAAP
from DDE import DDE
from CTD import CTD
from QSOrder import QSOrder

# %% [markdown]
# ### Initial settings

# %%
random.seed(42)
np.random.seed(42)
random_state = 42
np.seterr(divide='ignore', invalid='ignore')
warnings.filterwarnings('ignore')
data_path = os.path.join(os.path.abspath('.'), 'datas')
feature_path = os.path.join(data_path, 'feature')
ifs_path = os.path.join(data_path, 'ifs')
bin_path = os.path.join(data_path, 'bin')
pos_num = 114
neg_num = 207
label = np.array([1] * pos_num + [0] * neg_num)
raw_fasta = os.path.join(data_path, 'data.fasta')

# %% [markdown]
# ### Feature extraction

# %%
# parameters of feature extraction methods
k, delta, nlag, w = 9, 10, 5, 0.5

pseck = PseCKSAAP(gap=k, delta=delta)
pseck.fit(raw_fasta)
pseck.encodings.to_csv(os.path.join(feature_path, 'feature_psecksaap.csv'))
print('feature psecksaap √')

dde = DDE()
dde.fit(raw_fasta)
dde.encodings.to_csv(os.path.join(feature_path, 'feature_dde.csv'))
print('feature dde √')

ctd = CTD()
ctd.fit(raw_fasta)
ctd.encodings.to_csv(os.path.join(feature_path, 'feature_ctd.csv'))
print('feature ctd √')

qso = QSOrder(nlag=nlag, w=w)
qso.fit(raw_fasta)
qso.encodings.to_csv(os.path.join(feature_path, 'feature_qsorder.csv'))
print('feature qsorder √')

feature_all = pd.concat(
    (
        pseck.encodings,
        dde.encodings.iloc[:, :],
        ctd.encodings.iloc[:, :],
        qso.encodings.iloc[:, :],
    ),
    axis=1,
    sort=False,
)
feature_all.to_csv(os.path.join(feature_path, 'feature_all.csv'))

# in this process:
# psecksaap + dde + ctd + qsorder
# 4140 + 400 + 273 + 50
names = ['P', 'PD', 'PDC', 'PDCQ']
lens = [
    len(pseck.headers),
    len(pseck.headers + dde.headers),
    len(pseck.headers + dde.headers + ctd.headers),
    len(pseck.headers + dde.headers + ctd.headers + qso.headers),
]
name_lens = dict(zip(names, lens))
del (raw_fasta, pseck, dde, ctd, qso)
# Out:
# psecksaap features 4.13 seconds
# feature psecksaap √
# feature dde √
# feature ctd √
# qsorder features comsumed 1.56 seconds
# feature qsorder √

# %% [markdown]
# ### Training and testing

# %%
# split dataset
X_train_pre, X_test_pre, y_train, y_test = train_test_split(
    feature_all,
    label,
    test_size=0.2,
    random_state=random_state,
    shuffle=True,
    stratify=label,
)

X_train_pre = pd.DataFrame(X_train_pre, columns=feature_all.columns)
pd.DataFrame(
    np.c_[y_train, X_train_pre],
    columns=['label'] + feature_all.columns.to_list(),
).to_csv(os.path.join(feature_path, 'feature_train.csv'), index=False)

X_test_pre = pd.DataFrame(X_test_pre, columns=feature_all.columns)
pd.DataFrame(
    np.c_[y_test, X_test_pre],
    columns=['label'] + feature_all.columns.to_list(),
).to_csv(os.path.join(feature_path, 'feature_test.csv'), index=False)

del feature_all

# %% [markdown]
# ### Feature selection
#
# #### 1. choose significant features

# %%
# ANOVA
Fscore, pvalue = f_classif(X_train_pre, y_train)
Fscore = pd.Series(Fscore, index=X_train_pre.columns).sort_values(
    ascending=False
)
Fscore.to_csv(os.path.join(data_path, "f_score.csv"), header=None)

Pvalue = pd.Series(pvalue, index=X_train_pre.columns).sort_values(
    ascending=True
)
Pvalue.to_csv(os.path.join(data_path, "p_value.csv"), header=None)

# feature significant // p < 0.05
feature_sig_columns = {
    name: X_train_pre.iloc[:, :lens]
    .reindex(columns=Pvalue[Pvalue < 0.05].dropna().index)
    .dropna(axis=1)
    .columns
    for name, lens in name_lens.items()
}
pd.DataFrame(
    dict([(k, pd.Series(v)) for k, v in feature_sig_columns.items()])
).to_csv(
    os.path.join(data_path, 'f_score_sig_features_by_methods.csv'), index=False
)

X_train_pre = X_train_pre[feature_sig_columns['PDCQ']]
X_train_pre.to_csv(os.path.join(feature_path, 'feature_train_sig.csv'))
X_test_pre = X_test_pre[feature_sig_columns['PDCQ']]
X_test_pre.to_csv(os.path.join(feature_path, 'feature_test_sig.csv'))

# %% [markdown]
# #### 2. scaling

# %%
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train_pre)

# save scaler
# input features of this scaler must be significant fetures
joblib.dump(scaler, os.path.join(bin_path, 'scaler_sig'))

X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train_pre.columns)
X_test_scaled = pd.DataFrame(
    scaler.transform(X_test_pre), columns=X_train_pre.columns
)

pd.DataFrame(
    np.c_[y_train, X_train_scaled],
    columns=['label'] + X_train_pre.columns.to_list(),
).to_csv(os.path.join(feature_path, 'train_sig.csv'), index=False)
pd.DataFrame(
    np.c_[y_test, X_test_scaled],
    columns=['label'] + X_train_pre.columns.to_list(),
).to_csv(os.path.join(feature_path, 'test_sig.csv'), index=False)

del X_train_pre, X_test_pre

# %% [markdown]
# #### 3. settings of training

# %%
cv = StratifiedKFold(n_splits=10)

# grid search cv --sklearn
base_grid_params = {
    'criterion': ['gini', 'entropy'],  # 2
    'max_depth': np.arange(5, 150, 35),  # 5
    'min_samples_split': np.arange(2, 30, 5),  # 6
    # 'min_samples_leaf': np.arange(1, 10, 2),  # 5
    'min_samples_leaf': [5],
    # 'max_leaf_nodes': np.arange(50, 200, 30),  # 5
    'max_leaf_nodes': [100],
    # 'ccp_alpha': np.logspace(-10, 0, num=6, base=10),  # 6
    'ccp_alpha': [1e-3],
    'n_estimators': np.logspace(1, 3, num=6, base=10, dtype=int),  # 6
}  # 360

# bayes search cv --skopt
base_bayes_params = {
    'criterion': ['gini', 'entropy'],
    'max_depth': (5, 150),
    'min_samples_split': (2, 30),
    'min_samples_leaf': (1, 10),
    'max_leaf_nodes': (50, 200),
    'ccp_alpha': (1e-10, 1.0, 'log-uniform'),
    'n_estimators': (10, 1000, 'log-uniform'),
}  # 64  ## dt + 1*(12-1) = 66 --> 64/68 --> 64


base_grid_cv = RF_GridCV(base_grid_params)
base_bayes_cv = RF_BayesCV(base_bayes_params)

# %% [markdown]
# #### 4. main IFS process

# %%
# test metrics: using for test results DataFrame columns
metrics = ['method', 'dimension', 'OA', 'AUC', 'MCC', 'Sn', 'Sp', 'AA']
# train columns
column_ = ['dimension', 'auc_mean', 'auc_std', 'estimator']

test_result_grid = pd.DataFrame([], columns=metrics)
test_roc_grid = pd.DataFrame(
    [], index=['fpr', 'tpr', 'thresholds'], columns=name_lens.keys()
)
test_result_bayes = pd.DataFrame([], columns=metrics)
test_roc_bayes = pd.DataFrame(
    [], index=['fpr', 'tpr', 'thresholds'], columns=name_lens.keys()
)

# P, PD, PDC, and PDCQ
for name, lens in name_lens.items():
    print('------------feature approach %s begin------------' % name)

    X_train = X_train_scaled[feature_sig_columns[name]]
    X_test = X_test_scaled[feature_sig_columns[name]]

    train_result_grid = pd.DataFrame([], columns=column_)
    # IFS, use no more than `num of training samples` features
    for i in range(1, X_train.shape[0] + 1):
        print('------------%d feature(s)------------' % i)

        try:
            base_clf_grid = base_grid_cv.fit(X_train.iloc[:, :i], y_train)
            cv_metric = [
                base_clf_grid.best_score_,
                base_clf_grid.cv_results_['std_test_score'][
                    base_clf_grid.best_index_
                ],
            ]

            train_result_grid = train_result_grid.append(
                dict(
                    zip(
                        column_,
                        [i] + cv_metric + [base_clf_grid.best_estimator_],
                    )
                ),
                ignore_index=True,
            )

        except Exception as e:
            print('Retry Failed! ', repr(e))
            train_result_grid = train_result_grid.append(
                dict(zip(column_, [i] + [np.NaN] * (len(column_) - 1))),
                ignore_index=True,
            )
        time.sleep(1)

    train_result_grid.to_csv(
        os.path.join(ifs_path, 'base_grid_ifs_' + name + '.csv'), index=False,
    )

    train_result_bayes = pd.DataFrame([], columns=column_)
    for i in range(1, X_train.shape[0] + 1):
        print('------------%d feature(s)------------' % i)

        try:
            base_clf_bayes = base_bayes_cv.fit(X_train.iloc[:, :i], y_train)
            cv_metric = [
                base_clf_bayes.best_score_,
                base_clf_bayes.cv_results_['std_test_score'][
                    base_clf_bayes.best_index_
                ],
            ]

            train_result_bayes = train_result_bayes.append(
                dict(
                    zip(
                        column_,
                        [i] + cv_metric + [base_clf_bayes.best_estimator_],
                    )
                ),
                ignore_index=True,
            )

        except Exception as e:
            print('Retry Failed! ', repr(e))
            train_result_bayes = train_result_bayes.append(
                dict(zip(column_, [i] + [np.NaN] * (len(column_) - 1))),
                ignore_index=True,
            )
        time.sleep(1)

    # all ifs of one method finished
    train_result_bayes.to_csv(
        os.path.join(ifs_path, 'base_bayes_ifs_' + name + '.csv'), index=False,
    )

    # test grid search
    d_grid, clf_grid = (
        train_result_grid.sort_values(
            by=['auc_mean', 'dimension'], ascending=[True, False]
        )
        .dropna()
        .iloc[-1, [0, -1]]
    )
    d_grid = int(d_grid)
    clf_grid.fit(X_train.iloc[:, :d_grid], y_train)

    joblib.dump(clf_grid, os.path.join(bin_path, 'base_grid_clf_' + name))

    # determine the thresholds
    y_pred_pro = (
        clf_grid.predict_proba(X_test.iloc[:, :d_grid])[:, 1]
        if hasattr(clf_grid, 'predict_proba')
        else clf_grid.decision_function(X_test.iloc[:, :d_grid])
    )

    fpr, tpr, thresholds = roc_curve(y_test, y_pred_pro)
    test_roc_grid.loc['fpr', name] = fpr.tolist()
    test_roc_grid.loc['tpr', name] = tpr.tolist()
    test_roc_grid.loc['thresholds', name] = thresholds.tolist()
    # tolist: for reading file, using eval()

    Youden_index = np.argmax(tpr - fpr)
    y_pred = y_pred_pro >= thresholds[Youden_index]

    # grid results
    test_result_grid = test_result_grid.append(
        dict(
            zip(
                metrics,
                [
                    name,
                    d_grid,
                    accuracy_score(y_test, y_pred),
                    roc_auc_score(y_test, y_pred_pro),
                    matthews_corrcoef(y_test, y_pred),
                    tpr[Youden_index],  # sn
                    1 - fpr[Youden_index],  # sp
                    balanced_accuracy_score(y_test, y_pred),
                ],
            )
        ),
        ignore_index=True,
    )

    # redundantly save test data
    test_result_grid.to_csv(
        os.path.join(data_path, 'base_grid_test_results.csv'), index=False
    )

    # test grid search
    d_bayes, clf_bayes = (
        train_result_bayes.sort_values(
            by=['auc_mean', 'dimension'], ascending=[True, False]
        )
        .dropna()
        .iloc[-1, [0, -1]]
    )
    d_bayes = int(d_bayes)
    clf_bayes.fit(X_train.iloc[:, :d_bayes], y_train)

    joblib.dump(clf_bayes, os.path.join(bin_path, 'base_bayes_clf_' + name))

    # determine thresholds
    y_pred_pro = (
        clf_bayes.predict_proba(X_test.iloc[:, :d_bayes])[:, 1]
        if hasattr(clf_bayes, 'predict_proba')
        else clf_bayes.decision_function(X_test.iloc[:, :d_bayes])
    )

    fpr, tpr, thresholds = roc_curve(y_test, y_pred_pro)
    test_roc_bayes.loc['fpr', name] = fpr.tolist()
    test_roc_bayes.loc['tpr', name] = tpr.tolist()
    test_roc_bayes.loc['thresholds', name] = thresholds.tolist()

    Youden_index = np.argmax(tpr - fpr)
    y_pred = y_pred_pro >= thresholds[Youden_index]

    # bayes results
    test_result_bayes = test_result_bayes.append(
        dict(
            zip(
                metrics,
                [
                    name,
                    d_bayes,
                    accuracy_score(y_test, y_pred),
                    roc_auc_score(y_test, y_pred_pro),
                    matthews_corrcoef(y_test, y_pred),
                    tpr[Youden_index],  # sn
                    1 - fpr[Youden_index],  # sp
                    balanced_accuracy_score(y_test, y_pred),
                ],
            )
        ),
        ignore_index=True,
    )

    test_result_bayes.to_csv(
        os.path.join(data_path, 'base_bayes_test_results.csv'), index=False
    )

test_roc_grid.to_csv(os.path.join(data_path, 'base_grid_test_roc.csv'))
test_roc_bayes.to_csv(os.path.join(data_path, 'base_bayes_test_roc.csv'))
# Out:
# ------------feature approach P begin------------
# ------------1 feature(s)------------
# RF GridSearchCV time: 141.5s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=5,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        min_samples_split=27, n_estimators=63, random_state=42)
# Best score:0.6511±0.0616
# ------------2 feature(s)------------
# RF GridSearchCV time: 141.0s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=5,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        min_samples_split=27, n_estimators=10, random_state=42)
# Best score:0.7308±0.0946
# ------------3 feature(s)------------
# RF GridSearchCV time: 141.9s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=5,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        min_samples_split=22, n_estimators=1000,
#                        random_state=42)
# Best score:0.7479±0.0784
# ------------4 feature(s)------------
# RF GridSearchCV time: 145.6s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=5, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=27,
#                        n_estimators=10, random_state=42)
# Best score:0.7500±0.0552
# ------------5 feature(s)------------
# RF GridSearchCV time: 164.6s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=5, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=27,
#                        n_estimators=1000, random_state=42)
# Best score:0.7775±0.1005
# ------------6 feature(s)------------
# RF GridSearchCV time: 152.4s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=5,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        min_samples_split=22, n_estimators=1000,
#                        random_state=42)
# Best score:0.8032±0.0885
# ------------7 feature(s)------------
# RF GridSearchCV time: 151.7s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=22,
#                        n_estimators=63, random_state=42)
# Best score:0.8047±0.0923
# ------------8 feature(s)------------
# RF GridSearchCV time: 138.9s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=5,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        min_samples_split=27, n_estimators=1000,
#                        random_state=42)
# Best score:0.8183±0.0878
# ------------9 feature(s)------------
# RF GridSearchCV time: 141.6s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=5,
#                        max_leaf_nodes=100, min_samples_leaf=5, n_estimators=63,
#                        random_state=42)
# Best score:0.8322±0.0852
# ------------10 feature(s)------------
# RF GridSearchCV time: 140.3s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5, n_estimators=398,
#                        random_state=42)
# Best score:0.8456±0.0785
# ------------11 feature(s)------------
# RF GridSearchCV time: 140.2s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=5,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        min_samples_split=27, n_estimators=158, random_state=42)
# Best score:0.8384±0.0762
# ------------12 feature(s)------------
# RF GridSearchCV time: 140.2s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=5,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        n_estimators=1000, random_state=42)
# Best score:0.8436±0.0745
# ------------13 feature(s)------------
# RF GridSearchCV time: 139.6s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=5, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=22,
#                        n_estimators=158, random_state=42)
# Best score:0.8498±0.0824
# ------------14 feature(s)------------
# RF GridSearchCV time: 139.9s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=5, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=12,
#                        n_estimators=63, random_state=42)
# Best score:0.8627±0.0645
# ------------15 feature(s)------------
# RF GridSearchCV time: 140.8s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=5,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        min_samples_split=17, n_estimators=158, random_state=42)
# Best score:0.8724±0.0471
# ------------16 feature(s)------------
# RF GridSearchCV time: 143.1s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, n_estimators=63, random_state=42)
# Best score:0.8675±0.0477
# ------------17 feature(s)------------
# RF GridSearchCV time: 138.3s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=5, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=27,
#                        n_estimators=1000, random_state=42)
# Best score:0.8691±0.0618
# ------------18 feature(s)------------
# RF GridSearchCV time: 136.4s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=22,
#                        n_estimators=158, random_state=42)
# Best score:0.8752±0.0548
# ------------19 feature(s)------------
# RF GridSearchCV time: 136.1s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        min_samples_split=27, n_estimators=158, random_state=42)
# Best score:0.8740±0.0619
# ------------20 feature(s)------------
# RF GridSearchCV time: 136.3s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=27,
#                        n_estimators=63, random_state=42)
# Best score:0.8760±0.0525
# ------------21 feature(s)------------
# RF GridSearchCV time: 136.5s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=5,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        min_samples_split=12, n_estimators=158, random_state=42)
# Best score:0.8858±0.0511
# ------------22 feature(s)------------
# RF GridSearchCV time: 137.6s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        n_estimators=1000, random_state=42)
# Best score:0.8838±0.0483
# ------------23 feature(s)------------
# RF GridSearchCV time: 136.2s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=5,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        min_samples_split=27, n_estimators=63, random_state=42)
# Best score:0.8934±0.0528
# ------------24 feature(s)------------
# RF GridSearchCV time: 136.3s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=5,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        min_samples_split=27, n_estimators=158, random_state=42)
# Best score:0.8905±0.0357
# ------------25 feature(s)------------
# RF GridSearchCV time: 138.9s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=5,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        min_samples_split=17, n_estimators=398, random_state=42)
# Best score:0.8885±0.0431
# ------------26 feature(s)------------
# RF GridSearchCV time: 139.1s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=22,
#                        n_estimators=1000, random_state=42)
# Best score:0.8879±0.0569
# ------------27 feature(s)------------
# RF GridSearchCV time: 138.4s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5, n_estimators=63,
#                        random_state=42)
# Best score:0.8883±0.0506
# ------------28 feature(s)------------
# RF GridSearchCV time: 139.5s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=12,
#                        n_estimators=1000, random_state=42)
# Best score:0.8827±0.0538
# ------------29 feature(s)------------
# RF GridSearchCV time: 142.2s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=17,
#                        n_estimators=1000, random_state=42)
# Best score:0.8867±0.0591
# ------------30 feature(s)------------
# RF GridSearchCV time: 145.8s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=5,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        min_samples_split=12, n_estimators=63, random_state=42)
# Best score:0.8857±0.0580
# ------------31 feature(s)------------
# RF GridSearchCV time: 146.0s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=17,
#                        n_estimators=158, random_state=42)
# Best score:0.8887±0.0632
# ------------32 feature(s)------------
# RF GridSearchCV time: 145.1s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=5,
#                        max_leaf_nodes=100, min_samples_leaf=5, n_estimators=158,
#                        random_state=42)
# Best score:0.8871±0.0479
# ------------33 feature(s)------------
# RF GridSearchCV time: 144.8s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        min_samples_split=12, n_estimators=63, random_state=42)
# Best score:0.8921±0.0456
# ------------34 feature(s)------------
# RF GridSearchCV time: 148.7s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=27,
#                        n_estimators=158, random_state=42)
# Best score:0.8878±0.0584
# ------------35 feature(s)------------
# RF GridSearchCV time: 158.9s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=5, max_leaf_nodes=100,
#                        min_samples_leaf=5, n_estimators=63, random_state=42)
# Best score:0.8885±0.0586
# ------------36 feature(s)------------
# RF GridSearchCV time: 149.3s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5, n_estimators=158,
#                        random_state=42)
# Best score:0.8839±0.0532
# ------------37 feature(s)------------
# RF GridSearchCV time: 149.7s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        min_samples_split=12, n_estimators=1000,
#                        random_state=42)
# Best score:0.8794±0.0644
# ------------38 feature(s)------------
# RF GridSearchCV time: 148.3s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, n_estimators=158, random_state=42)
# Best score:0.8843±0.0578
# ------------39 feature(s)------------
# RF GridSearchCV time: 166.2s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=5,
#                        max_leaf_nodes=100, min_samples_leaf=5, n_estimators=63,
#                        random_state=42)
# Best score:0.8861±0.0587
# ------------40 feature(s)------------
# RF GridSearchCV time: 151.6s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        min_samples_split=12, n_estimators=63, random_state=42)
# Best score:0.8882±0.0423
# ------------41 feature(s)------------
# RF GridSearchCV time: 154.6s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, n_estimators=158, random_state=42)
# Best score:0.8876±0.0500
# ------------42 feature(s)------------
# RF GridSearchCV time: 189.4s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        min_samples_split=17, n_estimators=158, random_state=42)
# Best score:0.8912±0.0563
# ------------43 feature(s)------------
# RF GridSearchCV time: 194.7s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, n_estimators=1000, random_state=42)
# Best score:0.8902±0.0451
# ------------44 feature(s)------------
# RF GridSearchCV time: 185.5s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=5, max_leaf_nodes=100,
#                        min_samples_leaf=5, n_estimators=25, random_state=42)
# Best score:0.8853±0.0480
# ------------45 feature(s)------------
# RF GridSearchCV time: 148.3s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        min_samples_split=27, n_estimators=1000,
#                        random_state=42)
# Best score:0.8882±0.0463
# ------------46 feature(s)------------
# RF GridSearchCV time: 148.1s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        n_estimators=1000, random_state=42)
# Best score:0.8842±0.0457
# ------------47 feature(s)------------
# RF GridSearchCV time: 151.0s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, n_estimators=1000, random_state=42)
# Best score:0.8849±0.0468
# ------------48 feature(s)------------
# RF GridSearchCV time: 164.0s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=22,
#                        n_estimators=63, random_state=42)
# Best score:0.8954±0.0430
# ------------49 feature(s)------------
# RF GridSearchCV time: 157.7s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=5, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=17,
#                        n_estimators=398, random_state=42)
# Best score:0.8895±0.0420
# ------------50 feature(s)------------
# RF GridSearchCV time: 173.3s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=12,
#                        n_estimators=398, random_state=42)
# Best score:0.8862±0.0432
# ------------51 feature(s)------------
# RF GridSearchCV time: 169.9s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=17,
#                        n_estimators=158, random_state=42)
# Best score:0.8903±0.0429
# ------------52 feature(s)------------
# RF GridSearchCV time: 164.2s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=12,
#                        n_estimators=1000, random_state=42)
# Best score:0.8895±0.0419
# ------------53 feature(s)------------
# RF GridSearchCV time: 158.0s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=12,
#                        n_estimators=1000, random_state=42)
# Best score:0.8854±0.0395
# ------------54 feature(s)------------
# RF GridSearchCV time: 160.7s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=12,
#                        n_estimators=1000, random_state=42)
# Best score:0.8843±0.0436
# ------------55 feature(s)------------
# RF GridSearchCV time: 159.7s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, n_estimators=1000, random_state=42)
# Best score:0.8849±0.0449
# ------------56 feature(s)------------
# RF GridSearchCV time: 154.5s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=5, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=27,
#                        n_estimators=158, random_state=42)
# Best score:0.8872±0.0498
# ------------57 feature(s)------------
# RF GridSearchCV time: 159.7s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=5, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=17,
#                        n_estimators=158, random_state=42)
# Best score:0.8924±0.0426
# ------------58 feature(s)------------
# RF GridSearchCV time: 159.1s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, n_estimators=1000, random_state=42)
# Best score:0.8850±0.0420
# ------------59 feature(s)------------
# RF GridSearchCV time: 157.9s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        min_samples_split=12, n_estimators=398, random_state=42)
# Best score:0.8878±0.0360
# ------------60 feature(s)------------
# RF GridSearchCV time: 163.9s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, n_estimators=158, random_state=42)
# Best score:0.8893±0.0404
# ------------61 feature(s)------------
# RF GridSearchCV time: 155.2s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=17,
#                        n_estimators=158, random_state=42)
# Best score:0.8933±0.0293
# ------------62 feature(s)------------
# RF GridSearchCV time: 156.5s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5, n_estimators=158,
#                        random_state=42)
# Best score:0.8871±0.0382
# ------------63 feature(s)------------
# RF GridSearchCV time: 160.3s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        n_estimators=1000, random_state=42)
# Best score:0.8852±0.0363
# ------------64 feature(s)------------
# RF GridSearchCV time: 149.6s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=22,
#                        n_estimators=1000, random_state=42)
# Best score:0.8869±0.0454
# ------------65 feature(s)------------
# RF GridSearchCV time: 156.9s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=22,
#                        n_estimators=1000, random_state=42)
# Best score:0.8862±0.0411
# ------------66 feature(s)------------
# RF GridSearchCV time: 151.9s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        min_samples_split=17, n_estimators=1000,
#                        random_state=42)
# Best score:0.8918±0.0349
# ------------67 feature(s)------------
# RF GridSearchCV time: 158.8s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=5, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=22,
#                        n_estimators=158, random_state=42)
# Best score:0.8895±0.0455
# ------------68 feature(s)------------
# RF GridSearchCV time: 161.7s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=22,
#                        n_estimators=1000, random_state=42)
# Best score:0.8913±0.0363
# ------------69 feature(s)------------
# RF GridSearchCV time: 156.9s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        min_samples_split=17, n_estimators=1000,
#                        random_state=42)
# Best score:0.8924±0.0380
# ------------70 feature(s)------------
# RF GridSearchCV time: 150.8s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        min_samples_split=17, n_estimators=1000,
#                        random_state=42)
# Best score:0.8848±0.0364
# ------------71 feature(s)------------
# RF GridSearchCV time: 154.2s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        min_samples_split=12, n_estimators=398, random_state=42)
# Best score:0.8865±0.0359
# ------------72 feature(s)------------
# RF GridSearchCV time: 157.1s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=22,
#                        n_estimators=1000, random_state=42)
# Best score:0.8867±0.0421
# ------------73 feature(s)------------
# RF GridSearchCV time: 154.0s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=5, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=22,
#                        n_estimators=1000, random_state=42)
# Best score:0.8821±0.0413
# ------------74 feature(s)------------
# RF GridSearchCV time: 150.8s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, n_estimators=1000, random_state=42)
# Best score:0.8847±0.0388
# ------------75 feature(s)------------
# RF GridSearchCV time: 158.8s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=5, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=22,
#                        n_estimators=398, random_state=42)
# Best score:0.8841±0.0423
# ------------76 feature(s)------------
# RF GridSearchCV time: 161.0s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=22,
#                        n_estimators=158, random_state=42)
# Best score:0.8939±0.0463
# ------------77 feature(s)------------
# RF GridSearchCV time: 157.3s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        min_samples_split=12, n_estimators=1000,
#                        random_state=42)
# Best score:0.8881±0.0407
# ------------78 feature(s)------------
# RF GridSearchCV time: 161.3s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=12,
#                        n_estimators=1000, random_state=42)
# Best score:0.8909±0.0396
# ------------79 feature(s)------------
# RF GridSearchCV time: 160.8s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=17,
#                        n_estimators=1000, random_state=42)
# Best score:0.8921±0.0364
# ------------80 feature(s)------------
# RF GridSearchCV time: 155.3s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        min_samples_split=17, n_estimators=398, random_state=42)
# Best score:0.8893±0.0318
# ------------81 feature(s)------------
# RF GridSearchCV time: 155.4s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=5, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=17,
#                        n_estimators=398, random_state=42)
# Best score:0.8871±0.0410
# ------------82 feature(s)------------
# RF GridSearchCV time: 184.0s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5, n_estimators=398,
#                        random_state=42)
# Best score:0.8860±0.0429
# ------------83 feature(s)------------
# RF GridSearchCV time: 169.2s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, n_estimators=398, random_state=42)
# Best score:0.8866±0.0424
# ------------84 feature(s)------------
# RF GridSearchCV time: 177.1s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        min_samples_split=12, n_estimators=1000,
#                        random_state=42)
# Best score:0.8873±0.0371
# ------------85 feature(s)------------
# RF GridSearchCV time: 172.8s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, n_estimators=1000, random_state=42)
# Best score:0.8855±0.0406
# ------------86 feature(s)------------
# RF GridSearchCV time: 167.5s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=5,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        min_samples_split=27, n_estimators=158, random_state=42)
# Best score:0.8864±0.0448
# ------------87 feature(s)------------
# RF GridSearchCV time: 163.3s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        min_samples_split=17, n_estimators=1000,
#                        random_state=42)
# Best score:0.8833±0.0396
# ------------88 feature(s)------------
# RF GridSearchCV time: 168.3s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, n_estimators=398, random_state=42)
# Best score:0.8888±0.0378
# ------------89 feature(s)------------
# RF GridSearchCV time: 167.2s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        n_estimators=1000, random_state=42)
# Best score:0.8884±0.0357
# ------------90 feature(s)------------
# RF GridSearchCV time: 160.0s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        min_samples_split=12, n_estimators=398, random_state=42)
# Best score:0.8925±0.0379
# ------------91 feature(s)------------
# RF GridSearchCV time: 159.3s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=5, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=17,
#                        n_estimators=25, random_state=42)
# Best score:0.8835±0.0362
# ------------92 feature(s)------------
# RF GridSearchCV time: 175.7s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, n_estimators=158, random_state=42)
# Best score:0.8925±0.0390
# ------------93 feature(s)------------
# RF GridSearchCV time: 170.9s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        min_samples_split=12, n_estimators=1000,
#                        random_state=42)
# Best score:0.8858±0.0336
# ------------94 feature(s)------------
# RF GridSearchCV time: 176.6s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=12,
#                        n_estimators=1000, random_state=42)
# Best score:0.8900±0.0334
# ------------95 feature(s)------------
# RF GridSearchCV time: 176.8s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, n_estimators=398, random_state=42)
# Best score:0.8931±0.0367
# ------------96 feature(s)------------
# RF GridSearchCV time: 191.1s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        min_samples_split=17, n_estimators=158, random_state=42)
# Best score:0.8871±0.0414
# ------------97 feature(s)------------
# RF GridSearchCV time: 170.7s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=12,
#                        n_estimators=158, random_state=42)
# Best score:0.8871±0.0429
# ------------98 feature(s)------------
# RF GridSearchCV time: 158.1s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, n_estimators=158, random_state=42)
# Best score:0.8944±0.0385
# ------------99 feature(s)------------
# RF GridSearchCV time: 158.3s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=27,
#                        n_estimators=398, random_state=42)
# Best score:0.8907±0.0380
# ------------100 feature(s)------------
# RF GridSearchCV time: 176.8s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=5, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=12,
#                        n_estimators=398, random_state=42)
# Best score:0.8926±0.0339
# ------------101 feature(s)------------
# RF GridSearchCV time: 176.8s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=12,
#                        n_estimators=398, random_state=42)
# Best score:0.8861±0.0403
# ------------102 feature(s)------------
# RF GridSearchCV time: 163.5s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, n_estimators=398, random_state=42)
# Best score:0.8884±0.0406
# ------------103 feature(s)------------
# RF GridSearchCV time: 169.8s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5, n_estimators=158,
#                        random_state=42)
# Best score:0.8903±0.0354
# ------------104 feature(s)------------
# RF GridSearchCV time: 169.2s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=27,
#                        n_estimators=158, random_state=42)
# Best score:0.9010±0.0408
# ------------105 feature(s)------------
# RF GridSearchCV time: 173.3s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        min_samples_split=22, n_estimators=158, random_state=42)
# Best score:0.8883±0.0344
# ------------106 feature(s)------------
# RF GridSearchCV time: 165.4s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        min_samples_split=12, n_estimators=158, random_state=42)
# Best score:0.8951±0.0398
# ------------107 feature(s)------------
# RF GridSearchCV time: 165.7s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=17,
#                        n_estimators=398, random_state=42)
# Best score:0.8887±0.0441
# ------------108 feature(s)------------
# RF GridSearchCV time: 160.1s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=5, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=27,
#                        n_estimators=63, random_state=42)
# Best score:0.8941±0.0388
# ------------109 feature(s)------------
# RF GridSearchCV time: 157.2s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=12,
#                        n_estimators=158, random_state=42)
# Best score:0.8905±0.0452
# ------------110 feature(s)------------
# RF GridSearchCV time: 163.6s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        n_estimators=1000, random_state=42)
# Best score:0.8903±0.0423
# ------------111 feature(s)------------
# RF GridSearchCV time: 171.7s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, n_estimators=1000, random_state=42)
# Best score:0.8911±0.0357
# ------------112 feature(s)------------
# RF GridSearchCV time: 157.9s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=5, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=12,
#                        n_estimators=63, random_state=42)
# Best score:0.8964±0.0454
# ------------113 feature(s)------------
# RF GridSearchCV time: 159.5s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=22,
#                        n_estimators=158, random_state=42)
# Best score:0.8934±0.0355
# ------------114 feature(s)------------
# RF GridSearchCV time: 159.4s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5, n_estimators=25,
#                        random_state=42)
# Best score:0.8953±0.0440
# ------------115 feature(s)------------
# RF GridSearchCV time: 160.2s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        n_estimators=1000, random_state=42)
# Best score:0.8924±0.0348
# ------------116 feature(s)------------
# RF GridSearchCV time: 159.9s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        n_estimators=1000, random_state=42)
# Best score:0.8918±0.0377
# ------------117 feature(s)------------
# RF GridSearchCV time: 159.9s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=5, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=27,
#                        n_estimators=1000, random_state=42)
# Best score:0.8934±0.0350
# ------------118 feature(s)------------
# RF GridSearchCV time: 160.3s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=12,
#                        n_estimators=1000, random_state=42)
# Best score:0.8899±0.0365
# ------------119 feature(s)------------
# RF GridSearchCV time: 153.0s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=5, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=12,
#                        n_estimators=398, random_state=42)
# Best score:0.8940±0.0353
# ------------120 feature(s)------------
# RF GridSearchCV time: 152.3s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        n_estimators=1000, random_state=42)
# Best score:0.8897±0.0389
# ------------121 feature(s)------------
# RF GridSearchCV time: 153.8s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5, n_estimators=398,
#                        random_state=42)
# Best score:0.8918±0.0382
# ------------122 feature(s)------------
# RF GridSearchCV time: 154.0s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, n_estimators=63, random_state=42)
# Best score:0.9041±0.0422
# ------------123 feature(s)------------
# RF GridSearchCV time: 154.2s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=17,
#                        n_estimators=398, random_state=42)
# Best score:0.8918±0.0372
# ------------124 feature(s)------------
# RF GridSearchCV time: 154.1s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=5, max_leaf_nodes=100,
#                        min_samples_leaf=5, n_estimators=63, random_state=42)
# Best score:0.8923±0.0380
# ------------125 feature(s)------------
# RF GridSearchCV time: 154.3s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, n_estimators=398, random_state=42)
# Best score:0.8923±0.0374
# ------------126 feature(s)------------
# RF GridSearchCV time: 154.9s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, n_estimators=1000, random_state=42)
# Best score:0.8880±0.0408
# ------------127 feature(s)------------
# RF GridSearchCV time: 153.9s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=5, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=17,
#                        n_estimators=158, random_state=42)
# Best score:0.8933±0.0324
# ------------128 feature(s)------------
# RF GridSearchCV time: 154.6s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=5,
#                        max_leaf_nodes=100, min_samples_leaf=5, n_estimators=398,
#                        random_state=42)
# Best score:0.8862±0.0401
# ------------129 feature(s)------------
# RF GridSearchCV time: 155.5s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=5,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        min_samples_split=12, n_estimators=1000,
#                        random_state=42)
# Best score:0.8867±0.0415
# ------------130 feature(s)------------
# RF GridSearchCV time: 154.4s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=17,
#                        n_estimators=158, random_state=42)
# Best score:0.8904±0.0342
# ------------131 feature(s)------------
# RF GridSearchCV time: 155.2s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        n_estimators=1000, random_state=42)
# Best score:0.8931±0.0335
# ------------132 feature(s)------------
# RF GridSearchCV time: 154.3s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=12,
#                        n_estimators=63, random_state=42)
# Best score:0.8902±0.0382
# ------------133 feature(s)------------
# RF GridSearchCV time: 155.9s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        min_samples_split=12, n_estimators=1000,
#                        random_state=42)
# Best score:0.8899±0.0367
# ------------134 feature(s)------------
# RF GridSearchCV time: 154.4s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=22,
#                        n_estimators=158, random_state=42)
# Best score:0.8934±0.0388
# ------------135 feature(s)------------
# RF GridSearchCV time: 155.5s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        n_estimators=1000, random_state=42)
# Best score:0.8872±0.0339
# ------------136 feature(s)------------
# RF GridSearchCV time: 154.5s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        min_samples_split=17, n_estimators=158, random_state=42)
# Best score:0.8868±0.0394
# ------------137 feature(s)------------
# RF GridSearchCV time: 154.5s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5, n_estimators=398,
#                        random_state=42)
# Best score:0.8864±0.0344
# ------------138 feature(s)------------
# RF GridSearchCV time: 154.3s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        min_samples_split=17, n_estimators=158, random_state=42)
# Best score:0.8895±0.0319
# ------------139 feature(s)------------
# RF GridSearchCV time: 154.3s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=5, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=12,
#                        n_estimators=158, random_state=42)
# Best score:0.8878±0.0411
# ------------140 feature(s)------------
# RF GridSearchCV time: 156.0s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, n_estimators=1000, random_state=42)
# Best score:0.8864±0.0412
# ------------141 feature(s)------------
# RF GridSearchCV time: 155.4s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        min_samples_split=12, n_estimators=1000,
#                        random_state=42)
# Best score:0.8879±0.0402
# ------------142 feature(s)------------
# RF GridSearchCV time: 154.5s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, n_estimators=158, random_state=42)
# Best score:0.8907±0.0420
# ------------143 feature(s)------------
# RF GridSearchCV time: 155.4s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        n_estimators=1000, random_state=42)
# Best score:0.8847±0.0418
# ------------144 feature(s)------------
# RF GridSearchCV time: 156.7s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5, n_estimators=63,
#                        random_state=42)
# Best score:0.9025±0.0354
# ------------145 feature(s)------------
# RF GridSearchCV time: 156.7s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=12,
#                        n_estimators=63, random_state=42)
# Best score:0.8920±0.0387
# ------------146 feature(s)------------
# RF GridSearchCV time: 158.3s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, n_estimators=1000, random_state=42)
# Best score:0.8887±0.0386
# ------------147 feature(s)------------
# RF GridSearchCV time: 157.9s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=12,
#                        n_estimators=1000, random_state=42)
# Best score:0.8902±0.0351
# ------------148 feature(s)------------
# RF GridSearchCV time: 157.8s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        min_samples_split=17, n_estimators=1000,
#                        random_state=42)
# Best score:0.8876±0.0318
# ------------149 feature(s)------------
# RF GridSearchCV time: 156.6s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=5, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=12,
#                        n_estimators=63, random_state=42)
# Best score:0.8915±0.0363
# ------------150 feature(s)------------
# RF GridSearchCV time: 157.1s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5, n_estimators=158,
#                        random_state=42)
# Best score:0.8919±0.0396
# ------------151 feature(s)------------
# RF GridSearchCV time: 157.2s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=12,
#                        n_estimators=398, random_state=42)
# Best score:0.8839±0.0305
# ------------152 feature(s)------------
# RF GridSearchCV time: 158.5s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        min_samples_split=12, n_estimators=398, random_state=42)
# Best score:0.8863±0.0345
# ------------153 feature(s)------------
# RF GridSearchCV time: 157.5s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, n_estimators=398, random_state=42)
# Best score:0.8834±0.0415
# ------------154 feature(s)------------
# RF GridSearchCV time: 157.6s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, n_estimators=398, random_state=42)
# Best score:0.8873±0.0356
# ------------155 feature(s)------------
# RF GridSearchCV time: 158.0s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, n_estimators=1000, random_state=42)
# Best score:0.8826±0.0382
# ------------156 feature(s)------------
# RF GridSearchCV time: 158.1s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, n_estimators=398, random_state=42)
# Best score:0.8880±0.0346
# ------------157 feature(s)------------
# RF GridSearchCV time: 157.3s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=40, max_leaf_nodes=100,
#                        min_samples_leaf=5, n_estimators=63, random_state=42)
# Best score:0.8906±0.0329
# ------------158 feature(s)------------
# RF GridSearchCV time: 158.1s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=40,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        n_estimators=1000, random_state=42)
# Best score:0.8850±0.0367
# ------------159 feature(s)------------
# RF GridSearchCV time: 157.6s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, max_depth=5, max_leaf_nodes=100,
#                        min_samples_leaf=5, min_samples_split=22,
#                        n_estimators=398, random_state=42)
# Best score:0.8858±0.0315
# ------------160 feature(s)------------
# RF GridSearchCV time: 157.2s
# Estimator: RandomForestClassifier(ccp_alpha=0.001, criterion='entropy', max_depth=5,
#                        max_leaf_nodes=100, min_samples_leaf=5,
#                        min_samples_split=22, n_estimators=63, random_state=42)
# Best score:0.8839±0.0325
# ------------161 feature(s)------------
# RF GridSearchCV time: 157.6s
# ...
# RF BayesSearchCV time: 104.1s
# Estimator: RandomForestClassifier(ccp_alpha=2.8700862440329734e-10, max_depth=150,
#                        max_leaf_nodes=92, min_samples_split=6, n_estimators=176,
#                        random_state=42)
# Best score:0.8791±0.0261
# ------------197 feature(s)------------
# RF BayesSearchCV time: 100.3s
# Estimator: RandomForestClassifier(ccp_alpha=5.068530285715764e-10, max_depth=150,
#                        max_leaf_nodes=50, n_estimators=106, random_state=42)
# Best score:0.8922±0.0365
# ------------198 feature(s)------------
# RF BayesSearchCV time: 117.4s
# Estimator: RandomForestClassifier(ccp_alpha=0.0028094212617050685, max_depth=70,
#                        max_leaf_nodes=50, n_estimators=153, random_state=42)
# Best score:0.8715±0.0453
# ------------199 feature(s)------------
# RF BayesSearchCV time: 127.9s
# Estimator: RandomForestClassifier(ccp_alpha=1e-10, max_depth=150, max_leaf_nodes=200,
#                        n_estimators=1000, random_state=42)
# Best score:0.8740±0.0338
# ------------200 feature(s)------------
# RF BayesSearchCV time: 128.4s
# Estimator: RandomForestClassifier(ccp_alpha=0.003624527868965649, max_depth=150,
#                        max_leaf_nodes=179, n_estimators=1000, random_state=42)
# Best score:0.8737±0.0377
# ------------201 feature(s)------------
# RF BayesSearchCV time: 117.3s
# Estimator: RandomForestClassifier(ccp_alpha=2.9921637358015938e-09, criterion='entropy',
#                        max_depth=150, max_leaf_nodes=200, n_estimators=1000,
#                        random_state=42)
# Best score:0.8681±0.0293
# ------------202 feature(s)------------
# RF BayesSearchCV time: 117.0s
# Estimator: RandomForestClassifier(ccp_alpha=1e-10, max_depth=119, max_leaf_nodes=50,
#                        n_estimators=1000, random_state=42)
# Best score:0.8731±0.0320
# ------------203 feature(s)------------
# RF BayesSearchCV time: 118.7s
# Estimator: RandomForestClassifier(ccp_alpha=0.00021369839129232936, max_depth=135,
#                        max_leaf_nodes=200, n_estimators=1000, random_state=42)
# Best score:0.8724±0.0448
# ------------204 feature(s)------------
# RF BayesSearchCV time: 122.5s
# Estimator: RandomForestClassifier(ccp_alpha=1.220749773310839e-10, max_depth=150,
#                        max_leaf_nodes=76, n_estimators=703, random_state=42)
# Best score:0.8722±0.0351
# ------------205 feature(s)------------
# RF BayesSearchCV time: 134.7s
# Estimator: RandomForestClassifier(ccp_alpha=3.1150800763190872e-06, max_depth=150,
#                        max_leaf_nodes=165, min_samples_split=7,
#                        n_estimators=1000, random_state=42)
# Best score:0.8707±0.0306
# ------------206 feature(s)------------
# RF BayesSearchCV time: 126.2s
# Estimator: RandomForestClassifier(ccp_alpha=7.709482178352237e-05, criterion='entropy',
#                        max_depth=105, max_leaf_nodes=200, n_estimators=1000,
#                        random_state=42)
# Best score:0.8748±0.0327
# ------------207 feature(s)------------
# RF BayesSearchCV time: 121.4s
# Estimator: RandomForestClassifier(ccp_alpha=5.26283604362901e-05, max_depth=150,
#                        max_leaf_nodes=200, n_estimators=600, random_state=42)
# Best score:0.8772±0.0391
# ------------208 feature(s)------------
# RF BayesSearchCV time: 119.5s
# Estimator: RandomForestClassifier(ccp_alpha=0.0001343035713497819, max_depth=109,
#                        max_leaf_nodes=187, n_estimators=1000, random_state=42)
# Best score:0.8762±0.0335
# ------------209 feature(s)------------
# RF BayesSearchCV time: 121.8s
# Estimator: RandomForestClassifier(ccp_alpha=1.642643350980776e-08, criterion='entropy',
#                        max_depth=80, max_leaf_nodes=133, n_estimators=1000,
#                        random_state=42)
# Best score:0.8801±0.0276
# ------------210 feature(s)------------
# RF BayesSearchCV time: 127.5s
# Estimator: RandomForestClassifier(ccp_alpha=1e-10, max_depth=130, max_leaf_nodes=200,
#                        n_estimators=1000, random_state=42)
# Best score:0.8807±0.0346
# ------------211 feature(s)------------
# RF BayesSearchCV time: 126.3s
# Estimator: RandomForestClassifier(ccp_alpha=1.6210192099754765e-06, max_depth=150,
#                        max_leaf_nodes=200, n_estimators=1000, random_state=42)
# Best score:0.8800±0.0305
# ------------212 feature(s)------------
# RF BayesSearchCV time: 131.3s
# Estimator: RandomForestClassifier(ccp_alpha=0.00010304260020137643, max_depth=133,
#                        max_leaf_nodes=200, min_samples_split=6,
#                        n_estimators=481, random_state=42)
# Best score:0.8855±0.0336
# ------------213 feature(s)------------
# RF BayesSearchCV time: 127.6s
# Estimator: RandomForestClassifier(ccp_alpha=1.725266831021039e-10, max_depth=150,
#                        max_leaf_nodes=50, n_estimators=1000, random_state=42)
# Best score:0.8805±0.0361
# ------------214 feature(s)------------
# RF BayesSearchCV time: 127.7s
# Estimator: RandomForestClassifier(ccp_alpha=8.130715246746978e-07, max_depth=91,
#                        max_leaf_nodes=74, n_estimators=775, random_state=42)
# Best score:0.8826±0.0264
# ------------215 feature(s)------------
# RF BayesSearchCV time: 116.6s
# Estimator: RandomForestClassifier(ccp_alpha=1.7318264027667106e-05, max_depth=150,
#                        max_leaf_nodes=89, n_estimators=407, random_state=42)
# Best score:0.8755±0.0285
# ------------216 feature(s)------------
# RF BayesSearchCV time: 120.0s
# Estimator: RandomForestClassifier(ccp_alpha=2.3379402410844493e-08, max_depth=150,
#                        max_leaf_nodes=50, n_estimators=1000, random_state=42)
# Best score:0.8766±0.0376
# ------------217 feature(s)------------
# RF BayesSearchCV time: 125.9s
# Estimator: RandomForestClassifier(ccp_alpha=3.195124286958983e-05, max_depth=106,
#                        max_leaf_nodes=62, min_samples_split=11,
#                        n_estimators=1000, random_state=42)
# Best score:0.8850±0.0326
# ------------218 feature(s)------------
# RF BayesSearchCV time: 121.9s
# Estimator: RandomForestClassifier(ccp_alpha=1e-10, max_depth=150, max_leaf_nodes=163,
#                        n_estimators=1000, random_state=42)
# Best score:0.8828±0.0342
# ------------219 feature(s)------------
# RF BayesSearchCV time: 119.1s
# Estimator: RandomForestClassifier(ccp_alpha=7.599450697171756e-10, max_depth=150,
#                        max_leaf_nodes=50, n_estimators=1000, random_state=42)
# Best score:0.8781±0.0367
# ------------220 feature(s)------------
# RF BayesSearchCV time: 116.0s
# Estimator: RandomForestClassifier(ccp_alpha=2.8351887003026884e-08, max_depth=150,
#                        max_leaf_nodes=200, n_estimators=336, random_state=42)
# Best score:0.8866±0.0358
# ------------221 feature(s)------------
# RF BayesSearchCV time: 130.8s
# Estimator: RandomForestClassifier(ccp_alpha=1.176529427615419e-06, max_depth=117,
#                        max_leaf_nodes=141, min_samples_split=6,
#                        n_estimators=976, random_state=42)
# Best score:0.8816±0.0338
# ------------222 feature(s)------------
# RF BayesSearchCV time: 128.7s
# Estimator: RandomForestClassifier(ccp_alpha=4.053912456909036e-09, max_depth=150,
#                        max_leaf_nodes=190, n_estimators=1000, random_state=42)
# Best score:0.8761±0.0348
# ------------223 feature(s)------------
# RF BayesSearchCV time: 113.1s
# Estimator: RandomForestClassifier(ccp_alpha=0.00013866755184318, max_depth=111,
#                        max_leaf_nodes=188, n_estimators=1000, random_state=42)
# Best score:0.8828±0.0412
# ------------224 feature(s)------------
# RF BayesSearchCV time: 112.7s
# Estimator: RandomForestClassifier(ccp_alpha=1.6829708777494593e-05, max_depth=150,
#                        max_leaf_nodes=50, n_estimators=1000, random_state=42)
# Best score:0.8784±0.0359
# ------------225 feature(s)------------
# RF BayesSearchCV time: 107.2s
# Estimator: RandomForestClassifier(ccp_alpha=1e-10, max_depth=150, max_leaf_nodes=50,
#                        n_estimators=191, random_state=42)
# Best score:0.8851±0.0415
# ------------226 feature(s)------------
# RF BayesSearchCV time: 123.4s
# Estimator: RandomForestClassifier(ccp_alpha=0.002687446572231792, criterion='entropy',
#                        max_depth=47, max_leaf_nodes=200, min_samples_split=3,
#                        n_estimators=1000, random_state=42)
# Best score:0.8739±0.0343
# ------------227 feature(s)------------
# RF BayesSearchCV time: 131.3s
# Estimator: RandomForestClassifier(ccp_alpha=0.00043950673748500686, max_depth=150,
#                        max_leaf_nodes=71, min_samples_split=3,
#                        n_estimators=1000, random_state=42)
# Best score:0.8789±0.0319
# ------------228 feature(s)------------
# RF BayesSearchCV time: 117.0s
# Estimator: RandomForestClassifier(ccp_alpha=0.0011904604806376763, max_depth=150,
#                        max_leaf_nodes=50, n_estimators=1000, random_state=42)
# Best score:0.8798±0.0339
# ------------229 feature(s)------------
# RF BayesSearchCV time: 104.3s
# Estimator: RandomForestClassifier(ccp_alpha=3.890452470381746e-09, max_depth=123,
#                        max_leaf_nodes=118, min_samples_split=6,
#                        n_estimators=117, random_state=42)
# Best score:0.8901±0.0359
# ------------230 feature(s)------------
# RF BayesSearchCV time: 128.8s
# Estimator: RandomForestClassifier(ccp_alpha=0.00010154316344057976, criterion='entropy',
#                        max_depth=150, max_leaf_nodes=77, n_estimators=1000,
#                        random_state=42)
# Best score:0.8786±0.0272
# ------------231 feature(s)------------
# RF BayesSearchCV time: 126.4s
# Estimator: RandomForestClassifier(ccp_alpha=3.460934775166942e-10, max_depth=146,
#                        max_leaf_nodes=200, n_estimators=1000, random_state=42)
# Best score:0.8870±0.0299
# ------------232 feature(s)------------
# RF BayesSearchCV time: 126.0s
# Estimator: RandomForestClassifier(ccp_alpha=3.4419087059746886e-06, max_depth=150,
#                        max_leaf_nodes=50, n_estimators=311, random_state=42)
# Best score:0.8891±0.0281
# ------------233 feature(s)------------
# RF BayesSearchCV time: 127.2s
# Estimator: RandomForestClassifier(ccp_alpha=2.4064405315984486e-07, max_depth=150,
#                        max_leaf_nodes=50, n_estimators=1000, random_state=42)
# Best score:0.8798±0.0329
# ------------234 feature(s)------------
# RF BayesSearchCV time: 125.6s
# Estimator: RandomForestClassifier(ccp_alpha=0.0001694815020553999, max_depth=150,
#                        max_leaf_nodes=200, n_estimators=185, random_state=42)
# Best score:0.8879±0.0298
# ------------235 feature(s)------------
# RF BayesSearchCV time: 111.6s
# Estimator: RandomForestClassifier(ccp_alpha=1.9316181547454878e-08, max_depth=89,
#                        max_leaf_nodes=50, n_estimators=1000, random_state=42)
# Best score:0.8820±0.0268
# ------------236 feature(s)------------
# RF BayesSearchCV time: 122.4s
# Estimator: RandomForestClassifier(ccp_alpha=0.0034997831444383842, max_depth=150,
#                        max_leaf_nodes=50, n_estimators=1000, random_state=42)
# Best score:0.8886±0.0265
# ------------237 feature(s)------------
# RF BayesSearchCV time: 109.0s
# Estimator: RandomForestClassifier(ccp_alpha=5.822727173498008e-06, max_depth=150,
#                        max_leaf_nodes=50, n_estimators=1000, random_state=42)
# Best score:0.8833±0.0285
# ------------238 feature(s)------------
# RF BayesSearchCV time: 128.9s
# Estimator: RandomForestClassifier(ccp_alpha=3.6212346273820253e-10, max_depth=150,
#                        max_leaf_nodes=50, n_estimators=1000, random_state=42)
# Best score:0.8801±0.0334
# ------------239 feature(s)------------
# RF BayesSearchCV time: 99.6s
# Estimator: RandomForestClassifier(ccp_alpha=4.1295138821854533e-08, max_depth=132,
#                        max_leaf_nodes=50, n_estimators=175, random_state=42)
# Best score:0.8962±0.0236
# ------------240 feature(s)------------
# RF BayesSearchCV time: 137.5s
# Estimator: RandomForestClassifier(ccp_alpha=0.0033745462750794796, max_depth=95,
#                        max_leaf_nodes=70, n_estimators=1000, random_state=42)
# Best score:0.8818±0.0230
# ------------241 feature(s)------------
# RF BayesSearchCV time: 117.8s
# Estimator: RandomForestClassifier(ccp_alpha=5.603699438237091e-10, max_depth=150,
#                        max_leaf_nodes=131, n_estimators=1000, random_state=42)
# Best score:0.8797±0.0306
# ------------242 feature(s)------------
# RF BayesSearchCV time: 128.1s
# Estimator: RandomForestClassifier(ccp_alpha=1e-10, max_depth=150, max_leaf_nodes=200,
#                        n_estimators=1000, random_state=42)
# Best score:0.8862±0.0252
# ------------243 feature(s)------------
# RF BayesSearchCV time: 124.7s
# Estimator: RandomForestClassifier(ccp_alpha=5.293592318275848e-10, max_depth=150,
#                        max_leaf_nodes=50, n_estimators=563, random_state=42)
# Best score:0.8838±0.0310
# ------------244 feature(s)------------
# RF BayesSearchCV time: 121.3s
# Estimator: RandomForestClassifier(ccp_alpha=8.061083066722869e-10, max_depth=150,
#                        max_leaf_nodes=50, n_estimators=301, random_state=42)
# Best score:0.8865±0.0321
# ------------245 feature(s)------------
# RF BayesSearchCV time: 124.6s
# Estimator: RandomForestClassifier(ccp_alpha=4.060322925116929e-10, max_depth=150,
#                        max_leaf_nodes=50, n_estimators=511, random_state=42)
# Best score:0.8876±0.0287
# ------------246 feature(s)------------
# RF BayesSearchCV time: 125.0s
# Estimator: RandomForestClassifier(ccp_alpha=3.811905101078235e-05, max_depth=129,
#                        max_leaf_nodes=158, n_estimators=952, random_state=42)
# Best score:0.8870±0.0265
# ------------247 feature(s)------------
# RF BayesSearchCV time: 137.5s
# Estimator: RandomForestClassifier(ccp_alpha=7.682774289697309e-10, max_depth=122,
#                        max_leaf_nodes=50, n_estimators=1000, random_state=42)
# Best score:0.8810±0.0332
# ------------248 feature(s)------------
# RF BayesSearchCV time: 114.3s
# Estimator: RandomForestClassifier(ccp_alpha=3.6083203709704706e-09, max_depth=150,
#                        max_leaf_nodes=50, n_estimators=365, random_state=42)
# Best score:0.8831±0.0233
# ------------249 feature(s)------------
# RF BayesSearchCV time: 134.8s
# Estimator: RandomForestClassifier(ccp_alpha=1e-10, max_depth=150, max_leaf_nodes=50,
#                        n_estimators=1000, random_state=42)
# Best score:0.8879±0.0288
# ------------250 feature(s)------------
# RF BayesSearchCV time: 126.2s
# Estimator: RandomForestClassifier(ccp_alpha=9.071362723218825e-05, max_depth=26,
#                        max_leaf_nodes=60, n_estimators=1000, random_state=42)
# Best score:0.8820±0.0365
# ------------251 feature(s)------------
# RF BayesSearchCV time: 125.2s
# Estimator: RandomForestClassifier(ccp_alpha=2.6276723735930836e-05, max_depth=150,
#                        max_leaf_nodes=200, n_estimators=1000, random_state=42)
# Best score:0.8792±0.0304
# ------------252 feature(s)------------
# RF BayesSearchCV time: 114.2s
# Estimator: RandomForestClassifier(ccp_alpha=1.2480677052153568e-07, max_depth=150,
#                        max_leaf_nodes=200, min_samples_split=10,
#                        n_estimators=1000, random_state=42)
# Best score:0.8835±0.0326
# ------------253 feature(s)------------
# RF BayesSearchCV time: 120.5s
# Estimator: RandomForestClassifier(ccp_alpha=2.548407909496704e-10, max_depth=99,
#                        max_leaf_nodes=200, min_samples_split=3,
#                        n_estimators=1000, random_state=42)
# Best score:0.8829±0.0340
# ------------254 feature(s)------------
# RF BayesSearchCV time: 113.4s
# Estimator: RandomForestClassifier(ccp_alpha=0.0024893773375523095, max_depth=106,
#                        max_leaf_nodes=200, n_estimators=442, random_state=42)
# Best score:0.8909±0.0322
# ------------255 feature(s)------------
# RF BayesSearchCV time: 130.2s
# Estimator: RandomForestClassifier(ccp_alpha=1.3123891582887877e-10, max_depth=150,
#                        max_leaf_nodes=50, n_estimators=1000, random_state=42)
# Best score:0.8846±0.0322
# ------------256 feature(s)------------
# RF BayesSearchCV time: 108.4s
# Estimator: RandomForestClassifier(ccp_alpha=9.567233195182566e-08, max_depth=21,
#                        max_leaf_nodes=50, n_estimators=50, random_state=42)
# Best score:0.8942±0.0448

# %% [markdown]
# ### Comparison between different algorithms

# %%
# svm cv
# # inspired by orthogonal experimental design, but for ref only
# n=#choices >=2, if n>=12, then n=12, else n=n  # 12=n_jobs in CLfSearchCV defined
svm_params = [
    # 1*(12-1) + 1 = 12 --> 12
    ({'kernel': ['linear'], 'C': (0.5, 131072.0, 'log-uniform')}, 12),
    (
        {
            'kernel': ['sigmoid', 'rbf'],
            'C': (0.5, 131072.0, 'log-uniform'),  # 2^17
            'gamma': (0.0000152587890625, 4.0, 'log-uniform'),  # 2^(-16)
        },
        24,  # 1*(2-1) + 2*(12-1) + 1 = 24 --> 24
    ),
    (
        {
            'kernel': ['poly'],
            'C': (0.5, 131072.0, 'log-uniform'),
            'gamma': (0.0000152587890625, 4.0, 'log-uniform'),
            'degree': (1, 5),
        },
        28,  # 2*(12-1) + 1*(5-1) + 1 = 27 --> 24/28 --> 28
    ),
]

# decision tree cv
dt_params = {
    'criterion': ['gini', 'entropy'],
    'max_depth': (5, 150),
    'min_samples_split': (2, 30),
    'min_samples_leaf': (1, 10),
    'max_leaf_nodes': (50, 200),
    'ccp_alpha': (1e-10, 1.0, 'log-uniform'),
}  # 1*(2-1) + 4*(12-1) + 1*(10-1) + 1 = 55 --> 52/56 --> 56

# naive bayes cv
nb_params = {'var_smoothing': (1e-12, 100.0, 'log-uniform')}
# 1*(12-1) + 1 = 12 --> 12

# AdaBoost
abc_params = {
    'n_estimators': (10, 1000, 'log-uniform'),
    'learning_rate': (1e-3, 2.0, 'log-uniform'),
}  # 2*(12-1) + 1 = 23 --> 20/24 --> 24


svm_bayes = SVM_BayesCV(svm_params)
dt_bayes = DT_BayesCV(dt_params)
nb_bayes = NB_BayesCV(nb_params)
abc_bayes = ABC_BayesCV(abc_params)

# %%
# all clfs IFS processes with d of P/D/C/Q (best features)
feature_method = (
    test_result_bayes.sort_values(by='AUC', ascending=True)
    .dropna()
    .iloc[-1, 0]
)

X_train = X_train_scaled[feature_sig_columns[feature_method]]
X_test = X_test_scaled[feature_sig_columns[feature_method]]

column_ = ['dimension', 'auc_mean', 'auc_std', 'estimator']
metrics = ['classifier', 'dimension', 'OA', 'AUC', 'MCC', 'Sn', 'Sp', 'AA']
clfs = ['SVM', 'DT', 'NB', 'ABC']
clfs_ = dict(zip(clfs, [svm_bayes, dt_bayes, nb_bayes, abc_bayes]))

test_results = pd.DataFrame([], columns=metrics)
test_roc = pd.DataFrame([], index=['fpr', 'tpr', 'thresholds'], columns=clfs)
for clf_ in clfs:
    print(
        '-------------%s using %s IFS process -------------'
        % (feature_method, clf_)
    )

    train_results = pd.DataFrame([], columns=column_)
    for i in range(1, X_train.shape[0] + 1):
        print('------------%d feature(s)------------' % i)

        try:
            clf_bayes = clfs_[clf_].fit(
                X_train=X_train.iloc[:, :i], y_train=y_train
            )
            cv_metric = [
                clf_bayes.best_score_,
                clf_bayes.cv_results_['std_test_score'][clf_bayes.best_index_],
            ]

            train_results = train_results.append(
                dict(
                    zip(
                        column_, [i] + cv_metric + [clf_bayes.best_estimator_],
                    )
                ),
                ignore_index=True,
            )

        except Exception as e:
            print('Retry Failed! ', repr(e))
            train_results = train_results.append(
                dict(zip(column_, [i] + [np.NaN] * (len(column_) - 1))),
                ignore_index=True,
            )
        time.sleep(1)

    train_results.to_csv(
        os.path.join(ifs_path, clf_ + '_bayes_ifs.csv'), index=False
    )

    # test
    d, clf = (
        train_results.sort_values(
            by=['auc_mean', 'dimension'], ascending=[True, False]
        )
        .dropna()
        .iloc[-1, [0, -1]]
    )
    d = int(d)
    clf.fit(X_train.iloc[:, :d], y_train)
    joblib.dump(clf, os.path.join(bin_path, clf_ + '_bayes'))

    # determine the thresholds
    y_pred_pro = (
        clf.predict_proba(X_test.iloc[:, :d])[:, 1]
        if hasattr(clf, 'predict_proba')
        else clf.decision_function(X_test.iloc[:, :d])
    )

    fpr, tpr, thresholds = roc_curve(y_test, y_pred_pro)
    test_roc.loc['fpr', clf_] = fpr.tolist()
    test_roc.loc['tpr', clf_] = tpr.tolist()
    test_roc.loc['thresholds', clf_] = thresholds.tolist()

    Youden_index = np.argmax(tpr - fpr)
    y_pred = y_pred_pro >= thresholds[Youden_index]

    # results
    test_results = test_results.append(
        dict(
            zip(
                metrics,
                [
                    clf_,
                    d,
                    accuracy_score(y_test, y_pred),
                    roc_auc_score(y_test, y_pred_pro),
                    matthews_corrcoef(y_test, y_pred),
                    tpr[Youden_index],  # sn
                    1 - fpr[Youden_index],  # sp
                    balanced_accuracy_score(y_test, y_pred),
                ],
            )
        ),
        ignore_index=True,
    )
    test_results.to_csv(
        os.path.join(data_path, 'clfs_bayes_test_results.csv'), index=False
    )

test_roc.to_csv(os.path.join(data_path, 'clfs_test_roc.csv'))
with open(os.path.join(data_path, 'clfs_test_roc.csv'), 'a') as f:
    f.write('\n' + feature_method)
# Out:
# -------------PD using SVM IFS process -------------
# ------------1 feature(s)------------
# SVM BayesSearchCV time: 208.6s
# Estimator: SVC(C=0.5, gamma=0.5254801670314164, probability=True, random_state=42)
# Best score:0.7079±0.0709
# ------------2 feature(s)------------
# SVM BayesSearchCV time: 258.9s
# Estimator: SVC(C=125444.38082335534, gamma=0.003730393021427302, probability=True,
#     random_state=42)
# Best score:0.7264±0.0839
# ------------3 feature(s)------------
# SVM BayesSearchCV time: 30.9s
# Estimator: SVC(C=131072.0, degree=1, gamma=0.000534496296235932, kernel='poly',
#     probability=True, random_state=42)
# Best score:0.7327±0.0813
# ------------4 feature(s)------------
# SVM BayesSearchCV time: 537.4s
# Estimator: SVC(C=131072.0, gamma=0.0011396600001150258, probability=True, random_state=42)
# Best score:0.7953±0.0965
# ------------5 feature(s)------------
# SVM BayesSearchCV time: 795.6s
# Estimator: SVC(C=1.3033263118282936, gamma=4.520356090977864e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.7949±0.0957
# ------------6 feature(s)------------
# SVM BayesSearchCV time: 42.4s
# Estimator: SVC(C=1.3033263118282936, gamma=4.520356090977864e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.8048±0.0794
# ------------7 feature(s)------------
# SVM BayesSearchCV time: 38.5s
# Estimator: SVC(C=112287.6772014874, gamma=1.5372353711566853e-05, probability=True,
#     random_state=42)
# Best score:0.8166±0.0704
# ------------8 feature(s)------------
# SVM BayesSearchCV time: 77.3s
# Estimator: SVC(C=1.3033263118282936, gamma=4.520356090977864e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.8181±0.0811
# ------------9 feature(s)------------
# SVM BayesSearchCV time: 116.5s
# Estimator: SVC(C=0.5813869506517986, gamma=0.0001125085260131088, probability=True,
#     random_state=42)
# Best score:0.8262±0.0712
# ------------10 feature(s)------------
# SVM BayesSearchCV time: 40.1s
# Estimator: SVC(C=1.3033263118282936, gamma=4.520356090977864e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.8210±0.0654
# ------------11 feature(s)------------
# SVM BayesSearchCV time: 65.8s
# Estimator: SVC(C=37842.59090086371, gamma=1.5389204976064565e-05, probability=True,
#     random_state=42)
# Best score:0.8230±0.0715
# ------------12 feature(s)------------
# SVM BayesSearchCV time: 85.0s
# Estimator: SVC(C=441.06622691118537, degree=1, gamma=0.012652742268859147, kernel='poly',
#     probability=True, random_state=42)
# Best score:0.8332±0.0681
# ------------13 feature(s)------------
# SVM BayesSearchCV time: 80.8s
# Estimator: SVC(C=131072.0, gamma=1.52587890625e-05, kernel='sigmoid', probability=True,
#     random_state=42)
# Best score:0.8388±0.0638
# ------------14 feature(s)------------
# SVM BayesSearchCV time: 255.8s
# Estimator: SVC(C=17251.146618553477, gamma=0.022253143314410383, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.8462±0.0859
# ------------15 feature(s)------------
# SVM BayesSearchCV time: 108.1s
# Estimator: SVC(C=1.8499225278222957, kernel='linear', probability=True, random_state=42)
# Best score:0.8509±0.0766
# ------------16 feature(s)------------
# SVM BayesSearchCV time: 81.4s
# Estimator: SVC(C=131072.0, gamma=1.52587890625e-05, probability=True, random_state=42)
# Best score:0.8533±0.0836
# ------------17 feature(s)------------
# SVM BayesSearchCV time: 106.6s
# Estimator: SVC(C=37.944254324331894, degree=1, gamma=0.037565514297708325, kernel='poly',
#     probability=True, random_state=42)
# Best score:0.8553±0.0836
# ------------18 feature(s)------------
# SVM BayesSearchCV time: 109.5s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.8588±0.0803
# ------------19 feature(s)------------
# SVM BayesSearchCV time: 124.5s
# Estimator: SVC(C=1.8499225278222957, kernel='linear', probability=True, random_state=42)
# Best score:0.8596±0.0767
# ------------20 feature(s)------------
# SVM BayesSearchCV time: 100.3s
# Estimator: SVC(C=37842.59090086371, gamma=1.5389204976064565e-05, probability=True,
#     random_state=42)
# Best score:0.8692±0.0759
# ------------21 feature(s)------------
# SVM BayesSearchCV time: 112.8s
# Estimator: SVC(C=87629.49151420791, degree=2, gamma=0.0038884524879971836, kernel='poly',
#     probability=True, random_state=42)
# Best score:0.8672±0.0877
# ------------22 feature(s)------------
# SVM BayesSearchCV time: 113.0s
# Estimator: SVC(C=1.8499225278222957, kernel='linear', probability=True, random_state=42)
# Best score:0.8671±0.0740
# ------------23 feature(s)------------
# SVM BayesSearchCV time: 137.3s
# Estimator: SVC(C=131072.0, gamma=1.52587890625e-05, kernel='sigmoid', probability=True,
#     random_state=42)
# Best score:0.8632±0.0640
# ------------24 feature(s)------------
# SVM BayesSearchCV time: 172.2s
# Estimator: SVC(C=0.5, degree=1, gamma=0.41188357865171504, kernel='poly', probability=True,
#     random_state=42)
# Best score:0.8751±0.0617
# ------------25 feature(s)------------
# SVM BayesSearchCV time: 115.8s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.8813±0.0485
# ------------26 feature(s)------------
# SVM BayesSearchCV time: 417.0s
# Estimator: SVC(C=95.23871678213351, gamma=0.005939497595258687, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.8886±0.0503
# ------------27 feature(s)------------
# SVM BayesSearchCV time: 174.4s
# Estimator: SVC(C=95.23871678213351, gamma=0.005939497595258687, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.8895±0.0523
# ------------28 feature(s)------------
# SVM BayesSearchCV time: 159.9s
# Estimator: SVC(C=0.5, kernel='linear', probability=True, random_state=42)
# Best score:0.8887±0.0539
# ------------29 feature(s)------------
# SVM BayesSearchCV time: 180.7s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.8965±0.0456
# ------------30 feature(s)------------
# SVM BayesSearchCV time: 168.9s
# Estimator: SVC(C=0.5, kernel='linear', probability=True, random_state=42)
# Best score:0.8967±0.0503
# ------------31 feature(s)------------
# SVM BayesSearchCV time: 177.1s
# Estimator: SVC(C=95.23871678213351, gamma=0.005939497595258687, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9040±0.0472
# ------------32 feature(s)------------
# SVM BayesSearchCV time: 189.0s
# Estimator: SVC(C=0.5, kernel='linear', probability=True, random_state=42)
# Best score:0.9019±0.0483
# ------------33 feature(s)------------
# SVM BayesSearchCV time: 174.3s
# Estimator: SVC(C=0.5, kernel='linear', probability=True, random_state=42)
# Best score:0.9032±0.0465
# ------------34 feature(s)------------
# SVM BayesSearchCV time: 60.5s
# Estimator: SVC(C=95.23871678213351, gamma=0.005939497595258687, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9093±0.0488
# ------------35 feature(s)------------
# SVM BayesSearchCV time: 405.1s
# Estimator: SVC(C=0.7118129979837391, degree=1, gamma=3.540392921535545, kernel='poly',
#     probability=True, random_state=42)
# Best score:0.9087±0.0512
# ------------36 feature(s)------------
# SVM BayesSearchCV time: 514.5s
# Estimator: SVC(C=1.8499225278222957, kernel='linear', probability=True, random_state=42)
# Best score:0.9098±0.0415
# ------------37 feature(s)------------
# SVM BayesSearchCV time: 181.5s
# Estimator: SVC(C=95.23871678213351, gamma=0.005939497595258687, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9085±0.0431
# ------------38 feature(s)------------
# SVM BayesSearchCV time: 166.7s
# Estimator: SVC(C=57272.32365972037, gamma=0.006801748233871275, kernel='poly',
#     probability=True, random_state=42)
# Best score:0.9137±0.0476
# ------------39 feature(s)------------
# SVM BayesSearchCV time: 45.0s
# Estimator: SVC(C=0.5, kernel='linear', probability=True, random_state=42)
# Best score:0.9141±0.0391
# ------------40 feature(s)------------
# SVM BayesSearchCV time: 107.2s
# Estimator: SVC(C=6332.783065060955, degree=2, gamma=0.003982061724066444, kernel='poly',
#     probability=True, random_state=42)
# Best score:0.9109±0.0409
# ------------41 feature(s)------------
# SVM BayesSearchCV time: 165.7s
# Estimator: SVC(C=95.23871678213351, gamma=0.005939497595258687, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9162±0.0384
# ------------42 feature(s)------------
# SVM BayesSearchCV time: 85.7s
# Estimator: SVC(C=0.5, kernel='linear', probability=True, random_state=42)
# Best score:0.9188±0.0350
# ------------43 feature(s)------------
# SVM BayesSearchCV time: 170.1s
# Estimator: SVC(C=41.53204873174938, degree=2, gamma=0.18593273989012613, kernel='poly',
#     probability=True, random_state=42)
# Best score:0.9140±0.0449
# ------------44 feature(s)------------
# SVM BayesSearchCV time: 97.9s
# Estimator: SVC(C=0.5, kernel='linear', probability=True, random_state=42)
# Best score:0.9153±0.0422
# ------------45 feature(s)------------
# SVM BayesSearchCV time: 97.8s
# Estimator: SVC(C=131072.0, gamma=0.6313918048856094, probability=True, random_state=42)
# Best score:0.9230±0.0420
# ------------46 feature(s)------------
# SVM BayesSearchCV time: 29.6s
# Estimator: SVC(C=131072.0, gamma=0.005888815187600141, kernel='poly', probability=True,
#     random_state=42)
# Best score:0.9244±0.0473
# ------------47 feature(s)------------
# SVM BayesSearchCV time: 35.0s
# Estimator: SVC(C=0.5, kernel='linear', probability=True, random_state=42)
# Best score:0.9247±0.0339
# ------------48 feature(s)------------
# SVM BayesSearchCV time: 31.6s
# Estimator: SVC(C=51571.1567885981, degree=4, gamma=0.01739151471685423, kernel='poly',
#     probability=True, random_state=42)
# Best score:0.9248±0.0448
# ------------49 feature(s)------------
# SVM BayesSearchCV time: 47.0s
# Estimator: SVC(C=106817.11245682182, degree=4, gamma=0.0141757647254299, kernel='poly',
#     probability=True, random_state=42)
# Best score:0.9282±0.0446
# ------------50 feature(s)------------
# SVM BayesSearchCV time: 24.4s
# Estimator: SVC(C=51571.1567885981, degree=4, gamma=0.01739151471685423, kernel='poly',
#     probability=True, random_state=42)
# Best score:0.9283±0.0454
# ------------51 feature(s)------------
# SVM BayesSearchCV time: 26.7s
# Estimator: SVC(C=51571.1567885981, degree=4, gamma=0.01739151471685423, kernel='poly',
#     probability=True, random_state=42)
# Best score:0.9286±0.0426
# ------------52 feature(s)------------
# SVM BayesSearchCV time: 28.7s
# Estimator: SVC(C=2.1477599020714875, gamma=0.08910985561169578, probability=True,
#     random_state=42)
# Best score:0.9266±0.0304
# ------------53 feature(s)------------
# SVM BayesSearchCV time: 23.3s
# Estimator: SVC(C=131072.0, degree=4, gamma=0.01329551892746761, kernel='poly',
#     probability=True, random_state=42)
# Best score:0.9273±0.0408
# ------------54 feature(s)------------
# SVM BayesSearchCV time: 23.7s
# Estimator: SVC(C=1.5414881936386382, gamma=0.31838898298951995, kernel='poly',
#     probability=True, random_state=42)
# Best score:0.9294±0.0392
# ------------55 feature(s)------------
# SVM BayesSearchCV time: 22.0s
# Estimator: SVC(C=0.9721627109219979, kernel='linear', probability=True, random_state=42)
# Best score:0.9367±0.0313
# ------------56 feature(s)------------
# SVM BayesSearchCV time: 22.4s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9363±0.0347
# ------------57 feature(s)------------
# SVM BayesSearchCV time: 21.8s
# Estimator: SVC(C=17573.67305531634, degree=1, gamma=1.52587890625e-05, kernel='poly',
#     probability=True, random_state=42)
# Best score:0.9369±0.0353
# ------------58 feature(s)------------
# SVM BayesSearchCV time: 22.4s
# Estimator: SVC(C=0.981285536797331, kernel='linear', probability=True, random_state=42)
# Best score:0.9344±0.0341
# ------------59 feature(s)------------
# SVM BayesSearchCV time: 22.3s
# Estimator: SVC(C=1.071357621666214, kernel='linear', probability=True, random_state=42)
# Best score:0.9291±0.0344
# ------------60 feature(s)------------
# SVM BayesSearchCV time: 23.0s
# Estimator: SVC(C=0.9870371366380363, kernel='linear', probability=True, random_state=42)
# Best score:0.9317±0.0333
# ------------61 feature(s)------------
# SVM BayesSearchCV time: 22.4s
# Estimator: SVC(C=0.9868998607519262, kernel='linear', probability=True, random_state=42)
# Best score:0.9291±0.0354
# ------------62 feature(s)------------
# SVM BayesSearchCV time: 21.2s
# Estimator: SVC(C=95.23871678213351, gamma=0.005939497595258687, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9310±0.0349
# ------------63 feature(s)------------
# SVM BayesSearchCV time: 21.6s
# Estimator: SVC(C=95.23871678213351, gamma=0.005939497595258687, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9389±0.0307
# ------------64 feature(s)------------
# SVM BayesSearchCV time: 21.1s
# Estimator: SVC(C=95.23871678213351, gamma=0.005939497595258687, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9390±0.0312
# ------------65 feature(s)------------
# SVM BayesSearchCV time: 21.4s
# Estimator: SVC(C=35926.455843349286, degree=1, gamma=1.52587890625e-05, kernel='poly',
#     probability=True, random_state=42)
# Best score:0.9417±0.0333
# ------------66 feature(s)------------
# SVM BayesSearchCV time: 22.9s
# Estimator: SVC(C=95.23871678213351, gamma=0.005939497595258687, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9409±0.0317
# ------------67 feature(s)------------
# SVM BayesSearchCV time: 22.2s
# Estimator: SVC(C=1721.5719077912652, gamma=5.65904677938307e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9369±0.0322
# ------------68 feature(s)------------
# SVM BayesSearchCV time: 22.6s
# Estimator: SVC(C=1721.5719077912652, gamma=5.65904677938307e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9370±0.0310
# ------------69 feature(s)------------
# SVM BayesSearchCV time: 21.5s
# Estimator: SVC(C=1.1694088516245609, degree=2, gamma=0.0002679354143541398, kernel='poly',
#     probability=True, random_state=42)
# Best score:0.9385±0.0357
# ------------70 feature(s)------------
# SVM BayesSearchCV time: 21.9s
# Estimator: SVC(C=6506.894199925978, degree=5, gamma=0.034961039410350635, kernel='poly',
#     probability=True, random_state=42)
# Best score:0.9394±0.0302
# ------------71 feature(s)------------
# SVM BayesSearchCV time: 21.7s
# Estimator: SVC(C=1.1694088516245609, degree=2, gamma=0.0002679354143541398, kernel='poly',
#     probability=True, random_state=42)
# Best score:0.9325±0.0358
# ------------72 feature(s)------------
# SVM BayesSearchCV time: 21.9s
# Estimator: SVC(C=0.5, gamma=1.52587890625e-05, probability=True, random_state=42)
# Best score:0.9325±0.0372
# ------------73 feature(s)------------
# SVM BayesSearchCV time: 21.7s
# Estimator: SVC(C=1721.5719077912652, gamma=5.65904677938307e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9351±0.0338
# ------------74 feature(s)------------
# SVM BayesSearchCV time: 22.3s
# Estimator: SVC(C=1721.5719077912652, gamma=5.65904677938307e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9358±0.0324
# ------------75 feature(s)------------
# SVM BayesSearchCV time: 21.3s
# Estimator: SVC(C=1721.5719077912652, gamma=5.65904677938307e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9311±0.0346
# ------------76 feature(s)------------
# SVM BayesSearchCV time: 21.7s
# Estimator: SVC(C=8.080188527977729, gamma=0.007162613042119215, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9325±0.0360
# ------------77 feature(s)------------
# SVM BayesSearchCV time: 21.6s
# Estimator: SVC(C=0.6711306550711928, gamma=0.09185676461487949, probability=True,
#     random_state=42)
# Best score:0.9311±0.0338
# ------------78 feature(s)------------
# SVM BayesSearchCV time: 22.0s
# Estimator: SVC(C=1721.5719077912652, gamma=5.65904677938307e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9326±0.0390
# ------------79 feature(s)------------
# SVM BayesSearchCV time: 21.9s
# Estimator: SVC(C=1.1694088516245609, degree=2, gamma=0.0002679354143541398, kernel='poly',
#     probability=True, random_state=42)
# Best score:0.9344±0.0350
# ------------80 feature(s)------------
# SVM BayesSearchCV time: 22.4s
# Estimator: SVC(C=1721.5719077912652, gamma=5.65904677938307e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9312±0.0372
# ------------81 feature(s)------------
# SVM BayesSearchCV time: 21.3s
# Estimator: SVC(C=0.5, gamma=0.07735996361387254, probability=True, random_state=42)
# Best score:0.9311±0.0328
# ------------82 feature(s)------------
# SVM BayesSearchCV time: 20.4s
# Estimator: SVC(C=1721.5719077912652, gamma=5.65904677938307e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9271±0.0343
# ------------83 feature(s)------------
# SVM BayesSearchCV time: 22.0s
# Estimator: SVC(C=1721.5719077912652, gamma=5.65904677938307e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9296±0.0307
# ------------84 feature(s)------------
# SVM BayesSearchCV time: 21.7s
# Estimator: SVC(C=0.9436121130876105, gamma=0.06645158573322145, probability=True,
#     random_state=42)
# Best score:0.9336±0.0304
# ------------85 feature(s)------------
# SVM BayesSearchCV time: 21.8s
# Estimator: SVC(C=1.1694088516245609, degree=2, gamma=0.0002679354143541398, kernel='poly',
#     probability=True, random_state=42)
# Best score:0.9316±0.0306
# ------------86 feature(s)------------
# SVM BayesSearchCV time: 21.9s
# Estimator: SVC(C=0.5, gamma=0.10623562144743147, probability=True, random_state=42)
# Best score:0.9317±0.0346
# ------------87 feature(s)------------
# SVM BayesSearchCV time: 21.4s
# Estimator: SVC(C=1.1694088516245609, degree=2, gamma=0.0002679354143541398, kernel='poly',
#     probability=True, random_state=42)
# Best score:0.9297±0.0343
# ------------88 feature(s)------------
# SVM BayesSearchCV time: 21.3s
# Estimator: SVC(C=2707.854180310629, gamma=1.8621164972088707e-05, probability=True,
#     random_state=42)
# Best score:0.9344±0.0320
# ------------89 feature(s)------------
# SVM BayesSearchCV time: 20.9s
# Estimator: SVC(C=1721.5719077912652, gamma=5.65904677938307e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9337±0.0328
# ------------90 feature(s)------------
# SVM BayesSearchCV time: 23.3s
# Estimator: SVC(C=1721.5719077912652, gamma=5.65904677938307e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9324±0.0332
# ------------91 feature(s)------------
# SVM BayesSearchCV time: 22.0s
# Estimator: SVC(C=1721.5719077912652, gamma=5.65904677938307e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9324±0.0328
# ------------92 feature(s)------------
# SVM BayesSearchCV time: 21.6s
# Estimator: SVC(C=0.5476644285092093, degree=5, gamma=0.17716071996418306, kernel='poly',
#     probability=True, random_state=42)
# Best score:0.9343±0.0397
# ------------93 feature(s)------------
# SVM BayesSearchCV time: 22.4s
# Estimator: SVC(C=1721.5719077912652, gamma=5.65904677938307e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9325±0.0346
# ------------94 feature(s)------------
# SVM BayesSearchCV time: 22.0s
# Estimator: SVC(C=131072.0, gamma=0.0001713528578143244, kernel='poly', probability=True,
#     random_state=42)
# Best score:0.9322±0.0301
# ------------95 feature(s)------------
# SVM BayesSearchCV time: 21.6s
# Estimator: SVC(C=805.8587227156285, gamma=0.0017042572520803226, kernel='poly',
#     probability=True, random_state=42)
# Best score:0.9314±0.0299
# ------------96 feature(s)------------
# SVM BayesSearchCV time: 22.1s
# Estimator: SVC(C=5028.7204549124235, gamma=1.52587890625e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9358±0.0335
# ------------97 feature(s)------------
# SVM BayesSearchCV time: 21.5s
# Estimator: SVC(C=1.3127538318864713, gamma=0.0033004840173344505, kernel='poly',
#     probability=True, random_state=42)
# Best score:0.9355±0.0295
# ------------98 feature(s)------------
# SVM BayesSearchCV time: 22.0s
# Estimator: SVC(C=1.1694088516245609, degree=2, gamma=0.0002679354143541398, kernel='poly',
#     probability=True, random_state=42)
# Best score:0.9303±0.0339
# ------------99 feature(s)------------
# SVM BayesSearchCV time: 23.3s
# Estimator: SVC(C=1721.5719077912652, gamma=5.65904677938307e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9301±0.0414
# ------------100 feature(s)------------
# SVM BayesSearchCV time: 23.4s
# Estimator: SVC(C=0.5, gamma=0.16882129075559382, probability=True, random_state=42)
# Best score:0.9329±0.0397
# ------------101 feature(s)------------
# SVM BayesSearchCV time: 21.8s
# Estimator: SVC(C=0.5, gamma=0.17645988173573915, probability=True, random_state=42)
# Best score:0.9335±0.0405
# ------------102 feature(s)------------
# SVM BayesSearchCV time: 20.8s
# Estimator: SVC(C=0.5, gamma=0.05803387416929768, probability=True, random_state=42)
# Best score:0.9361±0.0313
# ------------103 feature(s)------------
# SVM BayesSearchCV time: 22.3s
# Estimator: SVC(C=0.5, gamma=0.08582225947497626, probability=True, random_state=42)
# Best score:0.9354±0.0331
# ------------104 feature(s)------------
# SVM BayesSearchCV time: 21.9s
# Estimator: SVC(C=0.5, gamma=0.08360275495503242, probability=True, random_state=42)
# Best score:0.9381±0.0320
# ------------105 feature(s)------------
# SVM BayesSearchCV time: 23.4s
# Estimator: SVC(C=0.5, gamma=0.08996431352913666, probability=True, random_state=42)
# Best score:0.9374±0.0312
# ------------106 feature(s)------------
# SVM BayesSearchCV time: 21.9s
# Estimator: SVC(C=0.5, gamma=0.09888281224621315, probability=True, random_state=42)
# Best score:0.9354±0.0337
# ------------107 feature(s)------------
# SVM BayesSearchCV time: 20.6s
# Estimator: SVC(C=0.5, gamma=0.09085697166222423, probability=True, random_state=42)
# Best score:0.9361±0.0328
# ------------108 feature(s)------------
# SVM BayesSearchCV time: 21.4s
# Estimator: SVC(C=0.5, gamma=0.07785386049931042, probability=True, random_state=42)
# Best score:0.9348±0.0343
# ------------109 feature(s)------------
# SVM BayesSearchCV time: 21.9s
# Estimator: SVC(C=0.5, gamma=0.08135196122543148, probability=True, random_state=42)
# Best score:0.9348±0.0354
# ------------110 feature(s)------------
# SVM BayesSearchCV time: 21.8s
# Estimator: SVC(C=0.5, gamma=0.12907957145299215, probability=True, random_state=42)
# Best score:0.9315±0.0408
# ------------111 feature(s)------------
# SVM BayesSearchCV time: 21.6s
# Estimator: SVC(C=0.5, gamma=0.09404762575507483, probability=True, random_state=42)
# Best score:0.9328±0.0377
# ------------112 feature(s)------------
# SVM BayesSearchCV time: 21.8s
# Estimator: SVC(C=0.5, gamma=0.11237828919408105, probability=True, random_state=42)
# Best score:0.9321±0.0420
# ------------113 feature(s)------------
# SVM BayesSearchCV time: 23.0s
# Estimator: SVC(C=0.5, gamma=0.09582420244751921, probability=True, random_state=42)
# Best score:0.9321±0.0390
# ------------114 feature(s)------------
# SVM BayesSearchCV time: 20.4s
# Estimator: SVC(C=0.5, gamma=0.08775620635764969, probability=True, random_state=42)
# Best score:0.9347±0.0359
# ------------115 feature(s)------------
# SVM BayesSearchCV time: 20.0s
# Estimator: SVC(C=0.5, gamma=1.8504491359512486e-05, kernel='poly', probability=True,
#     random_state=42)
# Best score:0.9340±0.0331
# ------------116 feature(s)------------
# SVM BayesSearchCV time: 21.3s
# Estimator: SVC(C=1721.5719077912652, gamma=5.65904677938307e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9318±0.0428
# ------------117 feature(s)------------
# SVM BayesSearchCV time: 19.4s
# Estimator: SVC(C=0.5, gamma=1.8504204403860636e-05, kernel='poly', probability=True,
#     random_state=42)
# Best score:0.9333±0.0304
# ------------118 feature(s)------------
# SVM BayesSearchCV time: 20.6s
# Estimator: SVC(C=1003.5060253020396, gamma=0.22752105999673802, probability=True,
#     random_state=42)
# Best score:0.9349±0.0397
# ------------119 feature(s)------------
# SVM BayesSearchCV time: 19.8s
# Estimator: SVC(C=2.1461650918025517, gamma=0.09293863680716151, probability=True,
#     random_state=42)
# Best score:0.9325±0.0408
# ------------120 feature(s)------------
# SVM BayesSearchCV time: 21.1s
# Estimator: SVC(C=1003.5060253020396, gamma=0.22752105999673802, probability=True,
#     random_state=42)
# Best score:0.9323±0.0396
# ------------121 feature(s)------------
# SVM BayesSearchCV time: 19.4s
# Estimator: SVC(C=131072.0, gamma=0.24225107913167718, probability=True, random_state=42)
# Best score:0.9397±0.0441
# ------------122 feature(s)------------
# SVM BayesSearchCV time: 18.3s
# Estimator: SVC(C=1003.5060253020396, gamma=0.22752105999673802, probability=True,
#     random_state=42)
# Best score:0.9482±0.0365
# ------------123 feature(s)------------
# SVM BayesSearchCV time: 19.5s
# Estimator: SVC(C=1003.5060253020396, gamma=0.22752105999673802, probability=True,
#     random_state=42)
# Best score:0.9488±0.0337
# ------------124 feature(s)------------
# SVM BayesSearchCV time: 19.6s
# Estimator: SVC(C=1003.5060253020396, gamma=0.22752105999673802, probability=True,
#     random_state=42)
# Best score:0.9481±0.0339
# ------------125 feature(s)------------
# SVM BayesSearchCV time: 20.6s
# Estimator: SVC(C=1003.5060253020396, gamma=0.22752105999673802, probability=True,
#     random_state=42)
# Best score:0.9488±0.0357
# ------------126 feature(s)------------
# SVM BayesSearchCV time: 20.6s
# Estimator: SVC(C=1003.5060253020396, gamma=0.22752105999673802, probability=True,
#     random_state=42)
# Best score:0.9467±0.0353
# ------------127 feature(s)------------
# SVM BayesSearchCV time: 18.8s
# Estimator: SVC(C=1003.5060253020396, gamma=0.22752105999673802, probability=True,
#     random_state=42)
# Best score:0.9480±0.0354
# ------------128 feature(s)------------
# SVM BayesSearchCV time: 20.5s
# Estimator: SVC(C=131072.0, gamma=0.19821201572943112, probability=True, random_state=42)
# Best score:0.9468±0.0316
# ------------129 feature(s)------------
# SVM BayesSearchCV time: 19.9s
# Estimator: SVC(C=1003.5060253020396, gamma=0.22752105999673802, probability=True,
#     random_state=42)
# Best score:0.9462±0.0343
# ------------130 feature(s)------------
# SVM BayesSearchCV time: 19.3s
# Estimator: SVC(C=1003.5060253020396, gamma=0.22752105999673802, probability=True,
#     random_state=42)
# Best score:0.9488±0.0345
# ------------131 feature(s)------------
# SVM BayesSearchCV time: 20.3s
# Estimator: SVC(C=1003.5060253020396, gamma=0.22752105999673802, probability=True,
#     random_state=42)
# Best score:0.9522±0.0339
# ------------132 feature(s)------------
# SVM BayesSearchCV time: 19.4s
# Estimator: SVC(C=705.3555453899044, gamma=0.21013042157848888, probability=True,
#     random_state=42)
# Best score:0.9487±0.0319
# ------------133 feature(s)------------
# SVM BayesSearchCV time: 19.9s
# Estimator: SVC(C=1003.5060253020396, gamma=0.22752105999673802, probability=True,
#     random_state=42)
# Best score:0.9481±0.0336
# ------------134 feature(s)------------
# SVM BayesSearchCV time: 17.3s
# Estimator: SVC(C=1003.5060253020396, gamma=0.22752105999673802, probability=True,
#     random_state=42)
# Best score:0.9495±0.0311
# ------------135 feature(s)------------
# SVM BayesSearchCV time: 19.9s
# Estimator: SVC(C=1003.5060253020396, gamma=0.22752105999673802, probability=True,
#     random_state=42)
# Best score:0.9482±0.0315
# ------------136 feature(s)------------
# SVM BayesSearchCV time: 20.8s
# Estimator: SVC(C=1003.5060253020396, gamma=0.22752105999673802, probability=True,
#     random_state=42)
# Best score:0.9490±0.0422
# ------------137 feature(s)------------
# SVM BayesSearchCV time: 19.8s
# Estimator: SVC(C=1003.5060253020396, gamma=0.22752105999673802, probability=True,
#     random_state=42)
# Best score:0.9496±0.0397
# ------------138 feature(s)------------
# SVM BayesSearchCV time: 19.3s
# Estimator: SVC(C=1003.5060253020396, gamma=0.22752105999673802, probability=True,
#     random_state=42)
# Best score:0.9497±0.0394
# ------------139 feature(s)------------
# SVM BayesSearchCV time: 18.3s
# Estimator: SVC(C=1003.5060253020396, gamma=0.22752105999673802, probability=True,
#     random_state=42)
# Best score:0.9483±0.0354
# ------------140 feature(s)------------
# SVM BayesSearchCV time: 19.0s
# Estimator: SVC(C=1003.5060253020396, gamma=0.22752105999673802, probability=True,
#     random_state=42)
# Best score:0.9490±0.0357
# ------------141 feature(s)------------
# SVM BayesSearchCV time: 19.7s
# Estimator: SVC(C=1003.5060253020396, gamma=0.22752105999673802, probability=True,
#     random_state=42)
# Best score:0.9503±0.0365
# ------------142 feature(s)------------
# SVM BayesSearchCV time: 18.8s
# Estimator: SVC(C=1003.5060253020396, gamma=0.22752105999673802, probability=True,
#     random_state=42)
# Best score:0.9496±0.0361
# ------------143 feature(s)------------
# SVM BayesSearchCV time: 21.2s
# Estimator: SVC(C=1003.5060253020396, gamma=0.22752105999673802, probability=True,
#     random_state=42)
# Best score:0.9496±0.0355
# ------------144 feature(s)------------
# SVM BayesSearchCV time: 21.1s
# Estimator: SVC(C=1003.5060253020396, gamma=0.22752105999673802, probability=True,
#     random_state=42)
# Best score:0.9496±0.0355
# ------------145 feature(s)------------
# SVM BayesSearchCV time: 19.5s
# Estimator: SVC(C=1003.5060253020396, gamma=0.22752105999673802, probability=True,
#     random_state=42)
# Best score:0.9509±0.0353
# ------------146 feature(s)------------
# SVM BayesSearchCV time: 19.0s
# Estimator: SVC(C=1003.5060253020396, gamma=0.22752105999673802, probability=True,
#     random_state=42)
# Best score:0.9508±0.0340
# ------------147 feature(s)------------
# SVM BayesSearchCV time: 20.8s
# Estimator: SVC(C=131037.66159971493, gamma=0.002238847217528629, kernel='poly',
#     probability=True, random_state=42)
# Best score:0.9487±0.0332
# ------------148 feature(s)------------
# SVM BayesSearchCV time: 19.3s
# Estimator: SVC(C=131072.0, gamma=0.25540691429833573, probability=True, random_state=42)
# Best score:0.9501±0.0325
# ------------149 feature(s)------------
# SVM BayesSearchCV time: 19.6s
# Estimator: SVC(C=0.5, kernel='linear', probability=True, random_state=42)
# Best score:0.9520±0.0327
# ------------150 feature(s)------------
# SVM BayesSearchCV time: 19.9s
# Estimator: SVC(C=131072.0, gamma=0.16302940864187312, probability=True, random_state=42)
# Best score:0.9528±0.0360
# ------------151 feature(s)------------
# SVM BayesSearchCV time: 20.5s
# Estimator: SVC(C=1003.5060253020396, gamma=0.22752105999673802, probability=True,
#     random_state=42)
# Best score:0.9523±0.0362
# ------------152 feature(s)------------
# SVM BayesSearchCV time: 19.9s
# Estimator: SVC(C=1003.5060253020396, gamma=0.22752105999673802, probability=True,
#     random_state=42)
# Best score:0.9516±0.0361
# ------------153 feature(s)------------
# SVM BayesSearchCV time: 20.6s
# Estimator: SVC(C=1003.5060253020396, gamma=0.22752105999673802, probability=True,
#     random_state=42)
# Best score:0.9503±0.0376
# ------------154 feature(s)------------
# SVM BayesSearchCV time: 20.2s
# Estimator: SVC(C=1003.5060253020396, gamma=0.22752105999673802, probability=True,
#     random_state=42)
# Best score:0.9510±0.0371
# ------------155 feature(s)------------
# SVM BayesSearchCV time: 19.1s
# Estimator: SVC(C=4.741210475392415, gamma=0.09369806382322887, probability=True,
#     random_state=42)
# Best score:0.9554±0.0305
# ------------156 feature(s)------------
# SVM BayesSearchCV time: 20.5s
# Estimator: SVC(C=117824.40610144717, gamma=0.975533909633297, kernel='poly',
#     probability=True, random_state=42)
# Best score:0.9477±0.0338
# ------------157 feature(s)------------
# SVM BayesSearchCV time: 19.9s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9486±0.0292
# ------------158 feature(s)------------
# SVM BayesSearchCV time: 20.1s
# Estimator: SVC(C=2.4296857542663557, gamma=0.06176169319328548, probability=True,
#     random_state=42)
# Best score:0.9522±0.0310
# ------------159 feature(s)------------
# SVM BayesSearchCV time: 18.8s
# Estimator: SVC(C=12778.520958390814, degree=4, gamma=0.01247380700145039, kernel='poly',
#     probability=True, random_state=42)
# Best score:0.9533±0.0342
# ------------160 feature(s)------------
# SVM BayesSearchCV time: 19.8s
# Estimator: SVC(C=3.246653400920758, gamma=0.1707418503810321, probability=True,
#     random_state=42)
# Best score:0.9554±0.0345
# ------------161 feature(s)------------
# SVM BayesSearchCV time: 21.0s
# Estimator: SVC(C=150.77346080897217, gamma=0.18895442547760982, probability=True,
#     random_state=42)
# Best score:0.9502±0.0345
# ------------162 feature(s)------------
# SVM BayesSearchCV time: 19.4s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9514±0.0271
# ------------163 feature(s)------------
# SVM BayesSearchCV time: 20.6s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9514±0.0276
# ------------164 feature(s)------------
# SVM BayesSearchCV time: 19.4s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9521±0.0282
# ------------165 feature(s)------------
# SVM BayesSearchCV time: 20.5s
# Estimator: SVC(C=3.8801097257484463, gamma=0.06961590334226395, probability=True,
#     random_state=42)
# Best score:0.9534±0.0276
# ------------166 feature(s)------------
# SVM BayesSearchCV time: 18.9s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9554±0.0266
# ------------167 feature(s)------------
# SVM BayesSearchCV time: 19.6s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9561±0.0273
# ------------168 feature(s)------------
# SVM BayesSearchCV time: 20.1s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9553±0.0243
# ------------169 feature(s)------------
# SVM BayesSearchCV time: 19.6s
# Estimator: SVC(C=17.299051385387695, gamma=0.004069190593321177, probability=True,
#     random_state=42)
# Best score:0.9513±0.0253
# ------------170 feature(s)------------
# SVM BayesSearchCV time: 21.8s
# Estimator: SVC(C=0.6683381476980762, degree=5, gamma=0.11872583921282785, kernel='poly',
#     probability=True, random_state=42)
# Best score:0.9512±0.0295
# ------------171 feature(s)------------
# SVM BayesSearchCV time: 19.5s
# Estimator: SVC(C=1721.5719077912652, gamma=5.65904677938307e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9500±0.0257
# ------------172 feature(s)------------
# SVM BayesSearchCV time: 21.3s
# Estimator: SVC(C=6567.736522071908, gamma=1.52587890625e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9506±0.0231
# ------------173 feature(s)------------
# SVM BayesSearchCV time: 19.9s
# Estimator: SVC(C=1721.5719077912652, gamma=5.65904677938307e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9486±0.0249
# ------------174 feature(s)------------
# SVM BayesSearchCV time: 20.4s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9487±0.0273
# ------------175 feature(s)------------
# SVM BayesSearchCV time: 20.3s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9533±0.0228
# ------------176 feature(s)------------
# SVM BayesSearchCV time: 19.8s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9533±0.0227
# ------------177 feature(s)------------
# SVM BayesSearchCV time: 19.4s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9560±0.0233
# ------------178 feature(s)------------
# SVM BayesSearchCV time: 19.3s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9567±0.0275
# ------------179 feature(s)------------
# SVM BayesSearchCV time: 19.7s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9562±0.0291
# ------------180 feature(s)------------
# SVM BayesSearchCV time: 18.5s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9549±0.0292
# ------------181 feature(s)------------
# SVM BayesSearchCV time: 20.1s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9549±0.0292
# ------------182 feature(s)------------
# SVM BayesSearchCV time: 20.2s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9549±0.0292
# ------------183 feature(s)------------
# SVM BayesSearchCV time: 19.8s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9569±0.0279
# ------------184 feature(s)------------
# SVM BayesSearchCV time: 20.5s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9555±0.0283
# ------------185 feature(s)------------
# SVM BayesSearchCV time: 21.5s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9549±0.0296
# ------------186 feature(s)------------
# SVM BayesSearchCV time: 19.7s
# Estimator: SVC(C=1721.5719077912652, gamma=5.65904677938307e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9541±0.0267
# ------------187 feature(s)------------
# SVM BayesSearchCV time: 19.9s
# Estimator: SVC(C=0.5586323861337978, degree=1, gamma=0.34323487510995754, kernel='poly',
#     probability=True, random_state=42)
# Best score:0.9555±0.0279
# ------------188 feature(s)------------
# SVM BayesSearchCV time: 18.3s
# Estimator: SVC(C=1721.5719077912652, gamma=5.65904677938307e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9547±0.0265
# ------------189 feature(s)------------
# SVM BayesSearchCV time: 20.8s
# Estimator: SVC(C=1721.5719077912652, gamma=5.65904677938307e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9560±0.0254
# ------------190 feature(s)------------
# SVM BayesSearchCV time: 20.0s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9542±0.0278
# ------------191 feature(s)------------
# SVM BayesSearchCV time: 19.4s
# Estimator: SVC(C=1721.5719077912652, gamma=5.65904677938307e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9554±0.0261
# ------------192 feature(s)------------
# SVM BayesSearchCV time: 19.4s
# Estimator: SVC(C=1721.5719077912652, gamma=5.65904677938307e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9574±0.0274
# ------------193 feature(s)------------
# SVM BayesSearchCV time: 21.6s
# Estimator: SVC(C=4492.476565131154, gamma=1.52587890625e-05, probability=True,
#     random_state=42)
# Best score:0.9568±0.0280
# ------------194 feature(s)------------
# SVM BayesSearchCV time: 20.5s
# Estimator: SVC(C=1721.5719077912652, gamma=5.65904677938307e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9581±0.0266
# ------------195 feature(s)------------
# SVM BayesSearchCV time: 20.2s
# Estimator: SVC(C=14.378077891267026, gamma=0.0034908481915272398, probability=True,
#     random_state=42)
# Best score:0.9561±0.0279
# ------------196 feature(s)------------
# SVM BayesSearchCV time: 18.9s
# Estimator: SVC(C=6.6332359159318885, degree=1, gamma=0.017679980429126597, kernel='poly',
#     probability=True, random_state=42)
# Best score:0.9555±0.0277
# ------------197 feature(s)------------
# SVM BayesSearchCV time: 21.4s
# Estimator: SVC(C=1721.5719077912652, gamma=5.65904677938307e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9534±0.0271
# ------------198 feature(s)------------
# SVM BayesSearchCV time: 19.8s
# Estimator: SVC(C=1721.5719077912652, gamma=5.65904677938307e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9541±0.0280
# ------------199 feature(s)------------
# SVM BayesSearchCV time: 20.3s
# Estimator: SVC(C=2.685942731877411, degree=2, gamma=0.08121822214584873, kernel='poly',
#     probability=True, random_state=42)
# Best score:0.9560±0.0222
# ------------200 feature(s)------------
# SVM BayesSearchCV time: 19.8s
# Estimator: SVC(C=1721.5719077912652, gamma=5.65904677938307e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9546±0.0247
# ------------201 feature(s)------------
# SVM BayesSearchCV time: 20.4s
# Estimator: SVC(C=1721.5719077912652, gamma=5.65904677938307e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9534±0.0275
# ------------202 feature(s)------------
# SVM BayesSearchCV time: 20.9s
# Estimator: SVC(C=25.443436615395807, gamma=0.0025012844964598536, probability=True,
#     random_state=42)
# Best score:0.9548±0.0274
# ------------203 feature(s)------------
# SVM BayesSearchCV time: 22.1s
# Estimator: SVC(C=1721.5719077912652, gamma=5.65904677938307e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9540±0.0274
# ------------204 feature(s)------------
# SVM BayesSearchCV time: 20.8s
# Estimator: SVC(C=1721.5719077912652, gamma=5.65904677938307e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9520±0.0266
# ------------205 feature(s)------------
# SVM BayesSearchCV time: 20.2s
# Estimator: SVC(C=147.52149160151922, gamma=0.00037006932651601496, probability=True,
#     random_state=42)
# Best score:0.9528±0.0294
# ------------206 feature(s)------------
# SVM BayesSearchCV time: 20.3s
# Estimator: SVC(C=4.834043059815776, degree=2, gamma=0.044662510092479304, kernel='poly',
#     probability=True, random_state=42)
# Best score:0.9548±0.0269
# ------------207 feature(s)------------
# SVM BayesSearchCV time: 19.2s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9524±0.0308
# ------------208 feature(s)------------
# SVM BayesSearchCV time: 19.2s
# Estimator: SVC(C=73.84729695265985, gamma=0.001884987303508152, probability=True,
#     random_state=42)
# Best score:0.9511±0.0318
# ------------209 feature(s)------------
# SVM BayesSearchCV time: 20.0s
# Estimator: SVC(C=130.1900795427459, gamma=0.0008667636294175327, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9508±0.0280
# ------------210 feature(s)------------
# SVM BayesSearchCV time: 20.2s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9518±0.0338
# ------------211 feature(s)------------
# SVM BayesSearchCV time: 20.2s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9537±0.0314
# ------------212 feature(s)------------
# SVM BayesSearchCV time: 20.6s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9557±0.0314
# ------------213 feature(s)------------
# SVM BayesSearchCV time: 20.4s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9537±0.0320
# ------------214 feature(s)------------
# SVM BayesSearchCV time: 20.1s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9531±0.0318
# ------------215 feature(s)------------
# SVM BayesSearchCV time: 20.6s
# Estimator: SVC(C=1721.5719077912652, gamma=5.65904677938307e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9543±0.0281
# ------------216 feature(s)------------
# SVM BayesSearchCV time: 19.9s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9543±0.0296
# ------------217 feature(s)------------
# SVM BayesSearchCV time: 20.2s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9563±0.0286
# ------------218 feature(s)------------
# SVM BayesSearchCV time: 21.0s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9542±0.0293
# ------------219 feature(s)------------
# SVM BayesSearchCV time: 20.0s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9543±0.0302
# ------------220 feature(s)------------
# SVM BayesSearchCV time: 20.7s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9536±0.0304
# ------------221 feature(s)------------
# SVM BayesSearchCV time: 21.3s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9544±0.0322
# ------------222 feature(s)------------
# SVM BayesSearchCV time: 21.2s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9543±0.0319
# ------------223 feature(s)------------
# SVM BayesSearchCV time: 20.4s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9557±0.0344
# ------------224 feature(s)------------
# SVM BayesSearchCV time: 21.6s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9602±0.0294
# ------------225 feature(s)------------
# SVM BayesSearchCV time: 21.0s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9595±0.0301
# ------------226 feature(s)------------
# SVM BayesSearchCV time: 21.5s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9583±0.0322
# ------------227 feature(s)------------
# SVM BayesSearchCV time: 21.4s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9595±0.0295
# ------------228 feature(s)------------
# SVM BayesSearchCV time: 21.0s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9595±0.0295
# ------------229 feature(s)------------
# SVM BayesSearchCV time: 22.3s
# Estimator: SVC(C=96.11457507316345, gamma=0.0017056082035616588, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9615±0.0283
# ------------230 feature(s)------------
# SVM BayesSearchCV time: 21.7s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9608±0.0295
# ------------231 feature(s)------------
# SVM BayesSearchCV time: 21.6s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9614±0.0285
# ------------232 feature(s)------------
# SVM BayesSearchCV time: 21.9s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9608±0.0295
# ------------233 feature(s)------------
# SVM BayesSearchCV time: 21.6s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9615±0.0292
# ------------234 feature(s)------------
# SVM BayesSearchCV time: 21.6s
# Estimator: SVC(C=10796.141849938856, gamma=2.1346792755332915e-05, kernel='sigmoid',
#     probability=True, random_state=42)
# Best score:0.9615±0.0292
# ...
#                    random_state=42)
# Best score:0.8864±0.0514
# ------------182 feature(s)------------
# ABC BayesSearchCV time: 50.5s
# Estimator: AdaBoostClassifier(learning_rate=0.45772540190283945, n_estimators=1000,
#                    random_state=42)
# Best score:0.8949±0.0487
# ------------183 feature(s)------------
# ABC BayesSearchCV time: 48.5s
# Estimator: AdaBoostClassifier(learning_rate=0.8366217780937628, n_estimators=1000,
#                    random_state=42)
# Best score:0.9007±0.0461
# ------------184 feature(s)------------
# ABC BayesSearchCV time: 46.6s
# Estimator: AdaBoostClassifier(learning_rate=0.5810909071553645, n_estimators=584,
#                    random_state=42)
# Best score:0.8904±0.0579
# ------------185 feature(s)------------
# ABC BayesSearchCV time: 55.4s
# Estimator: AdaBoostClassifier(learning_rate=0.8927427889438546, n_estimators=1000,
#                    random_state=42)
# Best score:0.9031±0.0492
# ------------186 feature(s)------------
# ABC BayesSearchCV time: 54.7s
# Estimator: AdaBoostClassifier(learning_rate=0.7816892427285866, n_estimators=1000,
#                    random_state=42)
# Best score:0.8952±0.0534
# ------------187 feature(s)------------
# ABC BayesSearchCV time: 47.8s
# Estimator: AdaBoostClassifier(learning_rate=0.5810909071553645, n_estimators=584,
#                    random_state=42)
# Best score:0.8864±0.0652
# ------------188 feature(s)------------
# ABC BayesSearchCV time: 52.1s
# Estimator: AdaBoostClassifier(learning_rate=0.8376858414802386, n_estimators=1000,
#                    random_state=42)
# Best score:0.8995±0.0426
# ------------189 feature(s)------------
# ABC BayesSearchCV time: 55.1s
# Estimator: AdaBoostClassifier(learning_rate=0.8288113921549692, n_estimators=1000,
#                    random_state=42)
# Best score:0.8927±0.0418
# ------------190 feature(s)------------
# ABC BayesSearchCV time: 51.9s
# Estimator: AdaBoostClassifier(learning_rate=0.8754951857342678, n_estimators=1000,
#                    random_state=42)
# Best score:0.8945±0.0331
# ------------191 feature(s)------------
# ABC BayesSearchCV time: 54.9s
# Estimator: AdaBoostClassifier(learning_rate=0.4247781566273817, n_estimators=1000,
#                    random_state=42)
# Best score:0.8894±0.0444
# ------------192 feature(s)------------
# ABC BayesSearchCV time: 55.1s
# Estimator: AdaBoostClassifier(learning_rate=0.576422005885251, n_estimators=1000,
#                    random_state=42)
# Best score:0.8895±0.0482
# ------------193 feature(s)------------
# ABC BayesSearchCV time: 53.2s
# Estimator: AdaBoostClassifier(learning_rate=0.7382619774139805, n_estimators=867,
#                    random_state=42)
# Best score:0.8942±0.0486
# ------------194 feature(s)------------
# ABC BayesSearchCV time: 55.6s
# Estimator: AdaBoostClassifier(learning_rate=0.6330243652065007, n_estimators=1000,
#                    random_state=42)
# Best score:0.8925±0.0454
# ------------195 feature(s)------------
# ABC BayesSearchCV time: 49.5s
# Estimator: AdaBoostClassifier(learning_rate=0.6982406039839691, n_estimators=891,
#                    random_state=42)
# Best score:0.8937±0.0515
# ------------196 feature(s)------------
# ABC BayesSearchCV time: 60.6s
# Estimator: AdaBoostClassifier(learning_rate=1.0407514674466463, n_estimators=1000,
#                    random_state=42)
# Best score:0.9019±0.0349
# ------------197 feature(s)------------
# ABC BayesSearchCV time: 51.4s
# Estimator: AdaBoostClassifier(learning_rate=0.8850104407667938, n_estimators=342,
#                    random_state=42)
# Best score:0.9014±0.0385
# ------------198 feature(s)------------
# ABC BayesSearchCV time: 55.4s
# Estimator: AdaBoostClassifier(learning_rate=0.9267672159446869, n_estimators=1000,
#                    random_state=42)
# Best score:0.9095±0.0416
# ------------199 feature(s)------------
# ABC BayesSearchCV time: 49.3s
# Estimator: AdaBoostClassifier(learning_rate=0.5221329172433163, n_estimators=1000,
#                    random_state=42)
# Best score:0.8904±0.0552
# ------------200 feature(s)------------
# ABC BayesSearchCV time: 52.9s
# Estimator: AdaBoostClassifier(learning_rate=0.6843951509178996, n_estimators=1000,
#                    random_state=42)
# Best score:0.8962±0.0526
# ------------201 feature(s)------------
# ABC BayesSearchCV time: 50.2s
# Estimator: AdaBoostClassifier(learning_rate=0.828828751104374, n_estimators=89,
#                    random_state=42)
# Best score:0.8878±0.0327
# ------------202 feature(s)------------
# ABC BayesSearchCV time: 52.1s
# Estimator: AdaBoostClassifier(learning_rate=0.6010181116657424, n_estimators=1000,
#                    random_state=42)
# Best score:0.8891±0.0544
# ------------203 feature(s)------------
# ABC BayesSearchCV time: 52.3s
# Estimator: AdaBoostClassifier(learning_rate=0.7506107270386231, n_estimators=478,
#                    random_state=42)
# Best score:0.8973±0.0441
# ------------204 feature(s)------------
# ABC BayesSearchCV time: 49.9s
# Estimator: AdaBoostClassifier(learning_rate=0.6768109722389194, n_estimators=1000,
#                    random_state=42)
# Best score:0.8977±0.0482
# ------------205 feature(s)------------
# ABC BayesSearchCV time: 53.0s
# Estimator: AdaBoostClassifier(learning_rate=0.4969987939005286, n_estimators=1000,
#                    random_state=42)
# Best score:0.8854±0.0508
# ------------206 feature(s)------------
# ABC BayesSearchCV time: 62.9s
# Estimator: AdaBoostClassifier(learning_rate=0.6588672379205092, n_estimators=1000,
#                    random_state=42)
# Best score:0.8994±0.0428
# ------------207 feature(s)------------
# ABC BayesSearchCV time: 55.9s
# Estimator: AdaBoostClassifier(learning_rate=0.7460728816118581, n_estimators=305,
#                    random_state=42)
# Best score:0.8887±0.0355
# ------------208 feature(s)------------
# ABC BayesSearchCV time: 44.8s
# Estimator: AdaBoostClassifier(learning_rate=0.68134309775686, n_estimators=1000,
#                    random_state=42)
# Best score:0.8989±0.0514
# ------------209 feature(s)------------
# ABC BayesSearchCV time: 49.0s
# Estimator: AdaBoostClassifier(learning_rate=0.7674584963797944, n_estimators=301,
#                    random_state=42)
# Best score:0.8932±0.0570
# ------------210 feature(s)------------
# ABC BayesSearchCV time: 53.4s
# Estimator: AdaBoostClassifier(learning_rate=0.9271658426184648, n_estimators=834,
#                    random_state=42)
# Best score:0.9060±0.0427
# ------------211 feature(s)------------
# ABC BayesSearchCV time: 56.3s
# Estimator: AdaBoostClassifier(learning_rate=0.8968488213354842, n_estimators=1000,
#                    random_state=42)
# Best score:0.9021±0.0434
# ------------212 feature(s)------------
# ABC BayesSearchCV time: 48.0s
# Estimator: AdaBoostClassifier(learning_rate=0.5147522623752554, n_estimators=1000,
#                    random_state=42)
# Best score:0.8948±0.0628
# ------------213 feature(s)------------
# ABC BayesSearchCV time: 56.0s
# Estimator: AdaBoostClassifier(learning_rate=0.39272543252406983, n_estimators=1000,
#                    random_state=42)
# Best score:0.8874±0.0556
# ------------214 feature(s)------------
# ABC BayesSearchCV time: 51.3s
# Estimator: AdaBoostClassifier(learning_rate=0.7245938199872739, n_estimators=285,
#                    random_state=42)
# Best score:0.8911±0.0440
# ------------215 feature(s)------------
# ABC BayesSearchCV time: 49.3s
# Estimator: AdaBoostClassifier(learning_rate=1.003410096425008, n_estimators=1000,
#                    random_state=42)
# Best score:0.9072±0.0460
# ------------216 feature(s)------------
# ABC BayesSearchCV time: 57.1s
# Estimator: AdaBoostClassifier(learning_rate=0.7523584383066645, n_estimators=816,
#                    random_state=42)
# Best score:0.8965±0.0414
# ------------217 feature(s)------------
# ABC BayesSearchCV time: 61.5s
# Estimator: AdaBoostClassifier(learning_rate=0.7743635367914364, n_estimators=1000,
#                    random_state=42)
# Best score:0.9105±0.0317
# ------------218 feature(s)------------
# ABC BayesSearchCV time: 56.8s
# Estimator: AdaBoostClassifier(learning_rate=0.7829167459149555, n_estimators=1000,
#                    random_state=42)
# Best score:0.9067±0.0438
# ------------219 feature(s)------------
# ABC BayesSearchCV time: 64.1s
# Estimator: AdaBoostClassifier(learning_rate=0.8142890155903986, n_estimators=1000,
#                    random_state=42)
# Best score:0.9094±0.0385
# ------------220 feature(s)------------
# ABC BayesSearchCV time: 52.6s
# Estimator: AdaBoostClassifier(learning_rate=0.9310642861313092, n_estimators=968,
#                    random_state=42)
# Best score:0.9084±0.0336
# ------------221 feature(s)------------
# ABC BayesSearchCV time: 50.8s
# Estimator: AdaBoostClassifier(learning_rate=0.5122445490708014, n_estimators=1000,
#                    random_state=42)
# Best score:0.9062±0.0552
# ------------222 feature(s)------------
# ABC BayesSearchCV time: 57.6s
# Estimator: AdaBoostClassifier(learning_rate=0.5791843720512646, n_estimators=1000,
#                    random_state=42)
# Best score:0.9048±0.0471
# ------------223 feature(s)------------
# ABC BayesSearchCV time: 53.1s
# Estimator: AdaBoostClassifier(learning_rate=0.36568835446644915, n_estimators=1000,
#                    random_state=42)
# Best score:0.8957±0.0610
# ------------224 feature(s)------------
# ABC BayesSearchCV time: 53.3s
# Estimator: AdaBoostClassifier(learning_rate=0.5370938131025366, n_estimators=1000,
#                    random_state=42)
# Best score:0.8933±0.0522
# ------------225 feature(s)------------
# ABC BayesSearchCV time: 55.6s
# Estimator: AdaBoostClassifier(learning_rate=0.5810909071553645, n_estimators=584,
#                    random_state=42)
# Best score:0.8947±0.0548
# ------------226 feature(s)------------
# ABC BayesSearchCV time: 46.5s
# Estimator: AdaBoostClassifier(learning_rate=0.5810909071553645, n_estimators=584,
#                    random_state=42)
# Best score:0.8947±0.0548
# ------------227 feature(s)------------
# ABC BayesSearchCV time: 53.1s
# Estimator: AdaBoostClassifier(learning_rate=0.5827725464004148, n_estimators=1000,
#                    random_state=42)
# Best score:0.8987±0.0494
# ------------228 feature(s)------------
# ABC BayesSearchCV time: 57.0s
# Estimator: AdaBoostClassifier(learning_rate=0.5963960835886075, n_estimators=987,
#                    random_state=42)
# Best score:0.8905±0.0519
# ------------229 feature(s)------------
# ABC BayesSearchCV time: 56.5s
# Estimator: AdaBoostClassifier(learning_rate=0.5646696365763181, n_estimators=1000,
#                    random_state=42)
# Best score:0.8952±0.0430
# ------------230 feature(s)------------
# ABC BayesSearchCV time: 58.8s
# Estimator: AdaBoostClassifier(learning_rate=0.596972095855823, n_estimators=987,
#                    random_state=42)
# Best score:0.8954±0.0461
# ------------231 feature(s)------------
# ABC BayesSearchCV time: 52.9s
# Estimator: AdaBoostClassifier(learning_rate=0.8990747006789577, n_estimators=454,
#                    random_state=42)
# Best score:0.9041±0.0576
# ------------232 feature(s)------------
# ABC BayesSearchCV time: 53.3s
# Estimator: AdaBoostClassifier(learning_rate=0.6486041225071951, n_estimators=1000,
#                    random_state=42)
# Best score:0.8952±0.0466
# ------------233 feature(s)------------
# ABC BayesSearchCV time: 58.3s
# Estimator: AdaBoostClassifier(learning_rate=0.5970085502140426, n_estimators=987,
#                    random_state=42)
# Best score:0.8944±0.0443
# ------------234 feature(s)------------
# ABC BayesSearchCV time: 53.4s
# Estimator: AdaBoostClassifier(learning_rate=0.7533773967172587, n_estimators=1000,
#                    random_state=42)
# Best score:0.8982±0.0576
# ------------235 feature(s)------------
# ABC BayesSearchCV time: 51.7s
# Estimator: AdaBoostClassifier(learning_rate=0.5418896417353829, n_estimators=1000,
#                    random_state=42)
# Best score:0.8900±0.0549
# ------------236 feature(s)------------
# ABC BayesSearchCV time: 57.7s
# Estimator: AdaBoostClassifier(learning_rate=0.8404573461391989, n_estimators=1000,
#                    random_state=42)
# Best score:0.8954±0.0557
# ------------237 feature(s)------------
# ABC BayesSearchCV time: 56.9s
# Estimator: AdaBoostClassifier(learning_rate=0.5810909071553645, n_estimators=584,
#                    random_state=42)
# Best score:0.8871±0.0368
# ------------238 feature(s)------------
# ABC BayesSearchCV time: 54.7s
# Estimator: AdaBoostClassifier(learning_rate=0.8594984422404226, n_estimators=542,
#                    random_state=42)
# Best score:0.8993±0.0470
# ------------239 feature(s)------------
# ABC BayesSearchCV time: 61.0s
# Estimator: AdaBoostClassifier(learning_rate=0.7968261322962875, n_estimators=1000,
#                    random_state=42)
# Best score:0.9063±0.0425
# ------------240 feature(s)------------
# ABC BayesSearchCV time: 59.2s
# Estimator: AdaBoostClassifier(learning_rate=0.6415595737059192, n_estimators=1000,
#                    random_state=42)
# Best score:0.8948±0.0500
# ------------241 feature(s)------------
# ABC BayesSearchCV time: 59.3s
# Estimator: AdaBoostClassifier(learning_rate=0.5057458542398309, n_estimators=970,
#                    random_state=42)
# Best score:0.8981±0.0496
# ------------242 feature(s)------------
# ABC BayesSearchCV time: 56.6s
# Estimator: AdaBoostClassifier(learning_rate=1.05589768902441, n_estimators=540,
#                    random_state=42)
# Best score:0.9063±0.0496
# ------------243 feature(s)------------
# ABC BayesSearchCV time: 48.9s
# Estimator: AdaBoostClassifier(learning_rate=0.5762970866033656, n_estimators=301,
#                    random_state=42)
# Best score:0.8865±0.0569
# ------------244 feature(s)------------
# ABC BayesSearchCV time: 57.9s
# Estimator: AdaBoostClassifier(learning_rate=0.6344666973874623, n_estimators=1000,
#                    random_state=42)
# Best score:0.8896±0.0449
# ------------245 feature(s)------------
# ABC BayesSearchCV time: 59.7s
# Estimator: AdaBoostClassifier(learning_rate=0.6381198298987646, n_estimators=1000,
#                    random_state=42)
# Best score:0.8858±0.0429
# ------------246 feature(s)------------
# ABC BayesSearchCV time: 63.1s
# Estimator: AdaBoostClassifier(learning_rate=0.6309333462466173, n_estimators=1000,
#                    random_state=42)
# Best score:0.8926±0.0545
# ------------247 feature(s)------------
# ABC BayesSearchCV time: 66.8s
# Estimator: AdaBoostClassifier(learning_rate=0.9829400461902458, n_estimators=1000,
#                    random_state=42)
# Best score:0.9086±0.0397
# ------------248 feature(s)------------
# ABC BayesSearchCV time: 73.4s
# Estimator: AdaBoostClassifier(learning_rate=1.1011743747296738, n_estimators=1000,
#                    random_state=42)
# Best score:0.9176±0.0355
# ------------249 feature(s)------------
# ABC BayesSearchCV time: 68.0s
# Estimator: AdaBoostClassifier(learning_rate=1.0914831616726992, n_estimators=1000,
#                    random_state=42)
# Best score:0.9105±0.0414
# ------------250 feature(s)------------
# ABC BayesSearchCV time: 68.2s
# Estimator: AdaBoostClassifier(learning_rate=1.025221901417281, n_estimators=696,
#                    random_state=42)
# Best score:0.9120±0.0347
# ------------251 feature(s)------------
# ABC BayesSearchCV time: 65.1s
# Estimator: AdaBoostClassifier(learning_rate=1.0488536254370378, n_estimators=1000,
#                    random_state=42)
# Best score:0.9024±0.0337
# ------------252 feature(s)------------
# ABC BayesSearchCV time: 68.9s
# Estimator: AdaBoostClassifier(learning_rate=1.14152841895425, n_estimators=1000,
#                    random_state=42)
# Best score:0.9098±0.0456
# ------------253 feature(s)------------
# ABC BayesSearchCV time: 65.7s
# Estimator: AdaBoostClassifier(learning_rate=1.028720976230575, n_estimators=1000,
#                    random_state=42)
# Best score:0.9085±0.0443
# ------------254 feature(s)------------
# ABC BayesSearchCV time: 65.8s
# Estimator: AdaBoostClassifier(learning_rate=1.3710397344429888, n_estimators=837,
#                    random_state=42)
# Best score:0.9257±0.0414
# ------------255 feature(s)------------
# ABC BayesSearchCV time: 66.2s
# Estimator: AdaBoostClassifier(learning_rate=0.7476157639296307, n_estimators=1000,
#                    random_state=42)
# Best score:0.8999±0.0450
# ------------256 feature(s)------------
# ABC BayesSearchCV time: 69.7s
# Estimator: AdaBoostClassifier(learning_rate=0.6332315764763154, n_estimators=1000,
#                    random_state=42)
# Best score:0.8972±0.0542
